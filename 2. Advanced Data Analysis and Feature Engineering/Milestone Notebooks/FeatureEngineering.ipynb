# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from itertools import combinations
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load data

# %%
train_cleaned = pd.read_csv("https://raw.githubusercontent.com/Ahmed-M-Fayad/Customer-Churn-Prediction-and-Analysis/main/Data%20Collection,%20Exploration,%20and%20Preprocessing/Delivered%20Data/train_cleaned_imputed.csv")
train_cleaned.head()
# Out:
#    age gender region_category  membership_category joining_date  \
# 0   18      F         Village  Platinum Membership   2017-08-17
# 1   32      F            City   Premium Membership   2017-08-28
# 2   44      F            Town        No Membership   2016-11-11
# 3   37      M            City        No Membership   2016-10-29
# 4   31      F            City        No Membership   2017-09-12
#
#   joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                      No     Gift Vouchers/Coupons             Desktop
# 1                      No     Gift Vouchers/Coupons             Desktop
# 2                     Yes     Gift Vouchers/Coupons             Desktop
# 3                     Yes     Gift Vouchers/Coupons             Desktop
# 4                      No  Credit/Debit Card Offers          Smartphone
#
#   internet_option last_visit_time  ...  avg_time_spent  avg_transaction_value  \
# 0           Wi-Fi        16:08:02  ...          300.63               53005.25
# 1     Mobile_Data        12:38:13  ...          306.34               12838.38
# 2           Wi-Fi        22:53:21  ...          516.16               21027.00
# 3     Mobile_Data        15:57:50  ...           53.27               25239.56
# 4     Mobile_Data        15:46:44  ...          113.13               24483.66
#
#    avg_frequency_login_days  points_in_wallet  used_special_discount  \
# 0                      17.0        781.750000                    Yes
# 1                      10.0        792.852122                    Yes
# 2                      22.0        500.690000                     No
# 3                       6.0        567.660000                     No
# 4                      16.0        663.060000                     No
#
#   offer_application_preference past_complaint     complaint_status  \
# 0                          Yes             No       Not Applicable
# 1                           No            Yes               Solved
# 2                          Yes            Yes  Solved in Follow-up
# 3                          Yes            Yes             Unsolved
# 4                          Yes            Yes               Solved
#
#                    feedback churn_risk_score
# 0  Products always in Stock              2.0
# 1     Quality Customer Care              1.0
# 2              Poor Website              5.0
# 3              Poor Website              5.0
# 4              Poor Website              5.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Create a copy for feature engineering

# %%
train_cleaned_copy = train_cleaned.copy()

# %% [markdown]
# ### Explore columns

# %%
train_cleaned_copy.columns
# Out:
# Index(['age', 'gender', 'region_category', 'membership_category',
#        'joining_date', 'joined_through_referral', 'preferred_offer_types',
#        'medium_of_operation', 'internet_option', 'last_visit_time',
#        'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
#        'avg_frequency_login_days', 'points_in_wallet', 'used_special_discount',
#        'offer_application_preference', 'past_complaint', 'complaint_status',
#        'feedback', 'churn_risk_score'],
#       dtype='object')

# %%
train_cleaned_copy.select_dtypes('number').columns
# Out:
# Index(['age', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'avg_frequency_login_days', 'points_in_wallet',
#        'churn_risk_score'],
#       dtype='object')

# %% [markdown]
# ### Extracting features

# %%
train_cleaned_copy['points_per_transaction'] = train_cleaned_copy['points_in_wallet'] / train_cleaned_copy['avg_transaction_value']
train_cleaned_copy['transaction_value_per_time_unit'] = train_cleaned_copy['avg_transaction_value'] / train_cleaned_copy['avg_time_spent']

# %%
def time_of_day(hour):
	if 5 <= hour < 12:
		return 'Morning'
	elif 12 <= hour < 17:
		return 'Afternoon'
	elif 17 <= hour < 21:
		return 'Evening'
	else:
		return 'Night'

# %%
def ampm_mapping(hour):
	if 0 <= hour < 12:
		return 'AM'
	else:
		return 'PM'

# %%
train_cleaned_copy['last_visit_hour'] = pd.to_datetime(train_cleaned_copy['last_visit_time']).dt.hour
train_cleaned_copy['last_visit_time_of_day'] = train_cleaned_copy['last_visit_hour'].apply(time_of_day)
train_cleaned_copy['last_visit_AMPM'] = train_cleaned_copy['last_visit_hour'].apply(ampm_mapping)

# %%
train_cleaned_copy['joining_date'] = pd.to_datetime(train_cleaned_copy['joining_date'])
train_cleaned_copy['joining_day_name'] = train_cleaned_copy['joining_date'].dt.day_name()

# %%
train_cleaned_copy['is_weekend'] = ((train_cleaned_copy['joining_day_name'] == 'Sunday') | 
									(train_cleaned_copy['joining_day_name'] == 'Saturday')).astype(int)

# %% [markdown]
# ### Save data (ready for advanced analysis)

# %%
train_cleaned_copy.isna().sum()
# Out:
# age                                0
# gender                             0
# region_category                    0
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# preferred_offer_types              0
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                   0
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# points_per_transaction             0
# transaction_value_per_time_unit    0
# last_visit_hour                    0
# last_visit_time_of_day             0
# last_visit_AMPM                    0
# joining_day_name                   0
# is_weekend                         0
# dtype: int64

# %%
train_cleaned_copy.to_csv('train_basicFeatureEng.csv', index=False)

# %%
train_cleaned_copy.select_dtypes(np.number).columns.tolist()
# Out:
# ['age',
#  'days_since_last_login',
#  'avg_time_spent',
#  'avg_transaction_value',
#  'avg_frequency_login_days',
#  'points_in_wallet',
#  'churn_risk_score',
#  'points_per_transaction',
#  'transaction_value_per_time_unit',
#  'last_visit_hour',
#  'is_weekend']

# %%
scale_cols = ['age', 'days_since_last_login', 'avg_time_spent', 'avg_transaction_value', 
			  'avg_frequency_login_days', 'points_in_wallet', 'points_per_transaction', 
              'transaction_value_per_time_unit', 'last_visit_hour']

# %% [markdown]
# ## Encoding categorical variables

# %%
for col in train_cleaned_copy.select_dtypes(exclude='number').columns:
	if col in ['joining_date', 'last_visit_time']:
		continue
	print(f'{col} Column', '-'*50)
	print(train_cleaned_copy[col].unique())
# Out:
# gender Column --------------------------------------------------
# ['F' 'M']
# region_category Column --------------------------------------------------
# ['Village' 'City' 'Town']
# membership_category Column --------------------------------------------------
# ['Platinum Membership' 'Premium Membership' 'No Membership'
#  'Gold Membership' 'Silver Membership' 'Basic Membership']
# joined_through_referral Column --------------------------------------------------
# ['No' 'Yes']
# preferred_offer_types Column --------------------------------------------------
# ['Gift Vouchers/Coupons' 'Credit/Debit Card Offers' 'Without Offers']
# medium_of_operation Column --------------------------------------------------
# ['Desktop' 'Smartphone' 'Both']
# internet_option Column --------------------------------------------------
# ['Wi-Fi' 'Mobile_Data' 'Fiber_Optic']
# used_special_discount Column --------------------------------------------------
# ['Yes' 'No']
# offer_application_preference Column --------------------------------------------------
# ['Yes' 'No']
# past_complaint Column --------------------------------------------------
# ['No' 'Yes']
# complaint_status Column --------------------------------------------------
# ['Not Applicable' 'Solved' 'Solved in Follow-up' 'Unsolved'
#  'No Information Available']
# feedback Column --------------------------------------------------
# ['Products always in Stock' 'Quality Customer Care' 'Poor Website'
#  'Too many ads' 'Poor Product Quality' 'Poor Customer Service'
#  'User Friendly Website' 'Reasonable Price']
# last_visit_time_of_day Column --------------------------------------------------
# ['Afternoon' 'Night' 'Morning' 'Evening']
# last_visit_AMPM Column --------------------------------------------------
# ['PM' 'AM']
# joining_day_name Column --------------------------------------------------
# ['Thursday' 'Monday' 'Friday' 'Saturday' 'Tuesday' 'Wednesday' 'Sunday']

# %%
one_hot_cols = list(set(train_cleaned_copy.select_dtypes(exclude='number').columns.tolist()) - 
					{'joining_date', 'last_visit_time'} - {'membership_category', 'feedback'})
one_hot_cols
# Out:
# ['joined_through_referral',
#  'joining_day_name',
#  'complaint_status',
#  'offer_application_preference',
#  'preferred_offer_types',
#  'gender',
#  'region_category',
#  'past_complaint',
#  'last_visit_time_of_day',
#  'medium_of_operation',
#  'internet_option',
#  'used_special_discount',
#  'last_visit_AMPM']

# %% [markdown]
# #### One-Hot Encoding (includes binary encoding)

# %%
train_cleaned_copy = pd.get_dummies(train_cleaned_copy, columns=one_hot_cols, drop_first=True, dtype=int)

# %% [markdown]
# #### Ordinal Encoding

# %%
# ordinal_cols = ['membership_category', 'feedback']
train_cleaned_copy['membership_category'] = pd.Categorical(train_cleaned_copy['membership_category'], 
														   categories=['No Membership', 'Basic Membership', 'Silver Membership', 
																	   'Gold Membership', 'Platinum Membership', 'Premium Membership'],
															ordered=True).codes

# %%
positive_feedback = ['Products always in Stock', 'Quality Customer Care', 'Reasonable Price', 'User Friendly Website']
negative_feedback = ['Poor Website' ,'Poor Customer Service', 'Poor Product Quality', 'Too many ads']
neutral_feedback = ['No reason specified']

def get_sentiment(feedback):
	if feedback in positive_feedback:
		return 1
	elif feedback in negative_feedback:
		return -1
	else:
		return 0 # neutral
	
train_cleaned_copy['feedback'] = train_cleaned_copy['feedback'].transform(get_sentiment)

# %% [markdown]
# #### General transformations numeric features

# %%
for num_col in train_cleaned_copy.select_dtypes(include=np.number).columns:
	train_cleaned_copy[f'{num_col}_sqrt'] = np.sqrt(train_cleaned_copy[num_col] + 1)
	train_cleaned_copy[f'{num_col}_square'] = np.square(train_cleaned_copy[num_col])
	train_cleaned_copy[f'{num_col}_log'] = np.log1p(train_cleaned_copy[num_col] + 0.01)

# %% [markdown]
# The cell below is from the EDA.ipynb notebook in milestone 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# log1p(x) = log(x + 1): this avoids errors when x = 0
train_cleaned_copy['log_avg_time_spent'] = np.log1p(train_cleaned_copy['avg_time_spent'])

fig, axes = plt.subplots(1, 2)
sns.violinplot(train_cleaned_copy['avg_time_spent'], ax=axes[0])
sns.violinplot(train_cleaned_copy['log_avg_time_spent'], ax=axes[1])
plt.tight_layout()
plt.show()

# %%
train_cleaned_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35829 entries, 0 to 35828
# Columns: 163 entries, age to log_avg_time_spent
# dtypes: datetime64[ns](1), float16(1), float64(96), int32(58), int64(4), int8(2), object(1)
# memory usage: 35.9+ MB

# %%
pd.set_option('display.max_rows', None)
train_cleaned_copy.corr(numeric_only=True)['churn_risk_score'].sort_values(ascending=False)
# Out:
# churn_risk_score                                      1.000000
# churn_risk_score_sqrt                                 0.996109
# churn_risk_score_log                                  0.983755
# churn_risk_score_square                               0.979841
# avg_frequency_login_days_log                          0.276144
# avg_frequency_login_days_sqrt                         0.259230
# avg_frequency_login_days                              0.238092
# avg_frequency_login_days_square                       0.183887
# joined_through_referral_Yes_sqrt                      0.070965
# joined_through_referral_Yes_log                       0.070965
# joined_through_referral_Yes                           0.070965
# joined_through_referral_Yes_square                    0.070965
# preferred_offer_types_Without Offers_log              0.062684
# preferred_offer_types_Without Offers_square           0.062684
# preferred_offer_types_Without Offers                  0.062684
# preferred_offer_types_Without Offers_sqrt             0.062684
# medium_of_operation_Smartphone                        0.048564
# medium_of_operation_Smartphone_square                 0.048564
# medium_of_operation_Smartphone_sqrt                   0.048564
# medium_of_operation_Smartphone_log                    0.048564
# points_per_transaction_log                            0.042879
# points_per_transaction_sqrt                           0.040117
# points_per_transaction                                0.037179
# days_since_last_login_log                             0.031116
# days_since_last_login_sqrt                            0.030501
# days_since_last_login                                 0.029158
# days_since_last_login_square                          0.025458
# region_category_Town                                  0.012645
# region_category_Town_square                           0.012645
# region_category_Town_log                              0.012645
# region_category_Town_sqrt                             0.012645
# past_complaint_Yes_sqrt                               0.012207
# past_complaint_Yes                                    0.012207
# past_complaint_Yes_square                             0.012207
# past_complaint_Yes_log                                0.012207
# points_per_transaction_square                         0.009452
# last_visit_time_of_day_Morning_log                    0.009076
# last_visit_time_of_day_Morning                        0.009076
# last_visit_time_of_day_Morning_square                 0.009076
# last_visit_time_of_day_Morning_sqrt                   0.009076
# complaint_status_Solved in Follow-up_square           0.008884
# complaint_status_Solved in Follow-up                  0.008884
# complaint_status_Solved in Follow-up_log              0.008884
# complaint_status_Solved in Follow-up_sqrt             0.008884
# complaint_status_Solved_square                        0.007241
# complaint_status_Solved                               0.007241
# complaint_status_Solved_log                           0.007241
# complaint_status_Solved_sqrt                          0.007241
# joining_day_name_Tuesday_log                          0.005528
# joining_day_name_Tuesday                              0.005528
# joining_day_name_Tuesday_square                       0.005528
# joining_day_name_Tuesday_sqrt                         0.005528
# joining_day_name_Monday_sqrt                          0.004507
# joining_day_name_Monday_square                        0.004507
# joining_day_name_Monday                               0.004507
# joining_day_name_Monday_log                           0.004507
# joining_day_name_Thursday_log                         0.004140
# joining_day_name_Thursday_square                      0.004140
# joining_day_name_Thursday                             0.004140
# joining_day_name_Thursday_sqrt                        0.004140
# age_log                                               0.002782
# age_sqrt                                              0.002615
# age                                                   0.002400
# joining_day_name_Saturday                             0.002120
# joining_day_name_Saturday_square                      0.002120
# joining_day_name_Saturday_log                         0.002120
# joining_day_name_Saturday_sqrt                        0.002120
# age_square                                            0.001991
# last_visit_time_of_day_Evening_sqrt                   0.001785
# last_visit_time_of_day_Evening_square                 0.001785
# last_visit_time_of_day_Evening                        0.001785
# last_visit_time_of_day_Evening_log                    0.001785
# internet_option_Mobile_Data_log                       0.001271
# internet_option_Mobile_Data                           0.001271
# internet_option_Mobile_Data_square                    0.001271
# internet_option_Mobile_Data_sqrt                      0.001271
# complaint_status_Unsolved_sqrt                       -0.001923
# complaint_status_Unsolved                            -0.001923
# complaint_status_Unsolved_square                     -0.001923
# complaint_status_Unsolved_log                        -0.001923
# internet_option_Wi-Fi_log                            -0.002215
# internet_option_Wi-Fi_square                         -0.002215
# internet_option_Wi-Fi                                -0.002215
# internet_option_Wi-Fi_sqrt                           -0.002215
# is_weekend_log                                       -0.003453
# is_weekend_sqrt                                      -0.003453
# is_weekend                                           -0.003453
# is_weekend_square                                    -0.003453
# gender_M_sqrt                                        -0.003978
# gender_M_log                                         -0.003978
# gender_M_square                                      -0.003978
# gender_M                                             -0.003978
# last_visit_time_of_day_Night_sqrt                    -0.004540
# last_visit_time_of_day_Night_log                     -0.004540
# last_visit_time_of_day_Night_square                  -0.004540
# last_visit_time_of_day_Night                         -0.004540
# joining_day_name_Wednesday_sqrt                      -0.006490
# joining_day_name_Wednesday                           -0.006490
# joining_day_name_Wednesday_square                    -0.006490
# joining_day_name_Wednesday_log                       -0.006490
# joining_day_name_Sunday_sqrt                         -0.006548
# joining_day_name_Sunday                              -0.006548
# joining_day_name_Sunday_square                       -0.006548
# joining_day_name_Sunday_log                          -0.006548
# last_visit_hour_log                                  -0.007059
# last_visit_hour_sqrt                                 -0.007428
# last_visit_hour_square                               -0.007578
# last_visit_hour                                      -0.007625
# last_visit_AMPM_PM_sqrt                              -0.008031
# last_visit_AMPM_PM_log                               -0.008031
# last_visit_AMPM_PM                                   -0.008031
# last_visit_AMPM_PM_square                            -0.008031
# used_special_discount_Yes_sqrt                       -0.010971
# used_special_discount_Yes_log                        -0.010971
# used_special_discount_Yes                            -0.010971
# used_special_discount_Yes_square                     -0.010971
# complaint_status_Not Applicable_log                  -0.012207
# complaint_status_Not Applicable_sqrt                 -0.012207
# complaint_status_Not Applicable_square               -0.012207
# complaint_status_Not Applicable                      -0.012207
# avg_time_spent_square                                -0.017077
# avg_time_spent                                       -0.027442
# avg_time_spent_sqrt                                  -0.032835
# medium_of_operation_Desktop_sqrt                     -0.034753
# medium_of_operation_Desktop_log                      -0.034753
# medium_of_operation_Desktop_square                   -0.034753
# medium_of_operation_Desktop                          -0.034753
# log_avg_time_spent                                   -0.035081
# avg_time_spent_log                                   -0.035081
# offer_application_preference_Yes_log                 -0.035571
# offer_application_preference_Yes                     -0.035571
# offer_application_preference_Yes_square              -0.035571
# offer_application_preference_Yes_sqrt                -0.035571
# region_category_Village                              -0.037567
# region_category_Village_square                       -0.037567
# region_category_Village_sqrt                         -0.037567
# region_category_Village_log                          -0.037567
# transaction_value_per_time_unit_square               -0.055716
# preferred_offer_types_Gift Vouchers/Coupons_log      -0.059039
# preferred_offer_types_Gift Vouchers/Coupons          -0.059039
# preferred_offer_types_Gift Vouchers/Coupons_square   -0.059039
# preferred_offer_types_Gift Vouchers/Coupons_sqrt     -0.059039
# transaction_value_per_time_unit_log                  -0.115171
# transaction_value_per_time_unit_sqrt                 -0.130417
# transaction_value_per_time_unit                      -0.137613
# avg_transaction_value_log                            -0.218185
# points_in_wallet_log                                 -0.288484
# avg_transaction_value_sqrt                           -0.297490
# points_in_wallet_square                              -0.316108
# points_in_wallet_sqrt                                -0.329870
# points_in_wallet                                     -0.343697
# avg_transaction_value                                -0.363009
# avg_transaction_value_square                         -0.430248
# membership_category_square                           -0.697186
# membership_category_log                              -0.737604
# feedback_log                                         -0.748908
# feedback_sqrt                                        -0.748908
# feedback                                             -0.748908
# membership_category_sqrt                             -0.755268
# membership_category                                  -0.756212
# feedback_square                                            NaN
# Name: churn_risk_score, dtype: float64

# %%
train_cleaned_copy.isna().sum()[train_cleaned_copy.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# features that we may need to transform are:
#
# - `avg_time_spent`:
#
# 	avg_time_spent                                       -0.027045
#
# 	avg_time_spent_sqrt                                  -0.031828
#
# 	avg_time_spent_log                                   -0.032828
#
# - `avg_transaction_value`:
#
# 	avg_transaction_value                                -0.362539
#
# 	avg_transaction_value_square                         -0.429874

# %%
scale_cols.append('avg_transaction_value_square')

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# ## Build Feature Engineering pipeline

# %% [markdown]
# ### FeatureEng custom transformer

# %%
# X is DataFrame of training features
# r_list is a list of desired combination sizes
# returns DataFrame with new combination features, excluding original categorical columns
def create_categorical_combinations(X, r_list, cat_cols):
	df_str = X[cat_cols].astype(str) # to allow concatenation
	for r in r_list:
		# generate all combinations of length r
		combinations_iter = combinations(cat_cols, r)
		for comb in combinations_iter:
			df_str['+'.join(comb)] = df_str[list(comb)].agg(''.join, axis=1)
	return df_str.drop(columns=cat_cols)

# %%
class FeatureEng(BaseEstimator, TransformerMixin):
	def __init__(self):
		self.membership_order = ['No Membership', 'Basic Membership', 'Silver Membership',
								 'Gold Membership', 'Platinum Membership', 'Premium Membership']
		self.positive_feedback = ['Products always in Stock', 'Quality Customer Care', 'Reasonable Price', 'User Friendly Website']
		self.negative_feedback = ['Poor Website', 'Poor Customer Service', 'Poor Product Quality', 'Too many ads']

	def time_of_day(self, hour):
		if 5 <= hour < 12:
			return 'Morning'
		elif 12 <= hour < 17:
			return 'Afternoon'
		elif 17 <= hour < 21:
			return 'Evening'
		else:
			return 'Night'
	
	def ampm_mapping(self, hour):
		return 'AM' if 0 <= hour < 12 else 'PM'

	def get_sentiment(self, feedback):
		if feedback in self.positive_feedback:
			return 1
		elif feedback in self.negative_feedback:
			return -1
		else:
			return 0

	def fit(self, X, y=None):
		return self

	def transform(self, X):
		X = X.copy()
		
		X['points_per_transaction'] = X['points_in_wallet'] / X['avg_transaction_value']
		X['transaction_value_per_time_unit'] = X['avg_transaction_value'] / X['avg_time_spent']
		
		X['last_visit_hour'] = pd.to_datetime(X['last_visit_time']).dt.hour
		X['last_visit_time_of_day'] = X['last_visit_hour'].apply(self.time_of_day)
		X['last_visit_AMPM'] = X['last_visit_hour'].apply(self.ampm_mapping)
		X.drop('last_visit_time', axis=1, inplace=True)
		
		X['joining_date'] = pd.to_datetime(X['joining_date'])
		X['joining_day_name'] = X['joining_date'].dt.day_name()
		X['is_weekend'] = X['joining_day_name'].isin(['Saturday', 'Sunday']).astype(int)
		X.drop('joining_date', axis=1, inplace=True)
		
		cat_cols = list(X.select_dtypes(include=['object', 'category']).columns)
		cat_combos_df = create_categorical_combinations(X, range(2, 3), cat_cols)
		X = pd.concat([X, cat_combos_df], axis=1)

		X['membership_category'] = pd.Categorical( X['membership_category'], 
												  categories=self.membership_order, 
												  ordered=True).codes

		X['feedback'] = X['feedback'].apply(self.get_sentiment)
		 
		X['avg_time_spent_log'] = np.log1p(X['avg_time_spent'])  
		X['avg_transaction_value_square'] = np.square(X['avg_transaction_value'])

		return X
	
	def fit_transform(self, X, y=None):
		X_transformed = self.transform(X)
		self.feature_names_out_ = X_transformed.columns
		return X_transformed
	
	def get_feature_names_out(self, input_features=None):
		return self.feature_names_out_

# %% [markdown]
# ### encoder_scaler transformer

# %%
encoder_scaler_transformer = ColumnTransformer([
	('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype=int), 
  make_column_selector(dtype_include=['object'])), 
	('scaler', StandardScaler(), scale_cols) 
], remainder='passthrough')

# %%
featureEng_encoder_scaler_pipeline = Pipeline([
    ('featureEng', FeatureEng()), 
    ('encoder_scaler', encoder_scaler_transformer)
])

# %%
train_split_cleaned_imputed = pd.read_csv("https://raw.githubusercontent.com/Ahmed-M-Fayad/Customer-Churn-Prediction-and-Analysis/main/Data%20Collection,%20Exploration,%20and%20Preprocessing/Delivered%20Data/train_split_cleaned_imputed.csv")

# %%
train_split_cleaned_imputed = pd.read_csv(r"D:\Courses\DEPI\Data Science\Project\Customer-Churn-Prediction-and-Analysis\Data Collection, Exploration, and Preprocessing\Delivered Data\train_split_cleaned_imputed.csv")

# %%
train_split_cleaned_imputed[train_split_cleaned_imputed.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, gender, region_category, membership_category, joining_date, joined_through_referral, preferred_offer_types, medium_of_operation, internet_option, last_visit_time, days_since_last_login, avg_time_spent, avg_transaction_value, avg_frequency_login_days, points_in_wallet, used_special_discount, offer_application_preference, past_complaint, complaint_status, feedback, churn_risk_score]
# Index: []
#
# [0 rows x 21 columns]

# %%
X_train = train_split_cleaned_imputed.drop(columns=['churn_risk_score'])
y_train = train_split_cleaned_imputed['churn_risk_score']

# %%
X_train['membership_category'].value_counts(dropna=False)
# Out:
# membership_category
# No Membership          5956
# Basic Membership       5953
# Gold Membership        5253
# Silver Membership      4702
# Premium Membership     3432
# Platinum Membership    3367
# Name: count, dtype: int64

# %%
X_train[X_train.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, gender, region_category, membership_category, joining_date, joined_through_referral, preferred_offer_types, medium_of_operation, internet_option, last_visit_time, days_since_last_login, avg_time_spent, avg_transaction_value, avg_frequency_login_days, points_in_wallet, used_special_discount, offer_application_preference, past_complaint, complaint_status, feedback]
# Index: []

# %%
X_train_preprocessed = featureEng_encoder_scaler_pipeline.fit_transform(X_train)

# %%
len(featureEng_encoder_scaler_pipeline.get_feature_names_out())
# Out:
# 1468

# %%
train_cleaned_copy.shape[1]
# Out:
# 163

# %%
np.isinf(X_train_preprocessed).sum()
# Out:
# 0

# %%
X_train_preprocessed = pd.DataFrame(X_train_preprocessed, 
                                    columns=featureEng_encoder_scaler_pipeline.get_feature_names_out())

# %%
X_train_preprocessed[X_train_preprocessed.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [encoder__gender_F, encoder__gender_M, encoder__gender_Unknown, encoder__region_category_City, encoder__region_category_Town, encoder__region_category_Village, encoder__joined_through_referral_No, encoder__joined_through_referral_Yes, encoder__preferred_offer_types_Credit/Debit Card Offers, encoder__preferred_offer_types_Gift Vouchers/Coupons, encoder__preferred_offer_types_Without Offers, encoder__medium_of_operation_Both, encoder__medium_of_operation_Desktop, encoder__medium_of_operation_Smartphone, encoder__internet_option_Fiber_Optic, encoder__internet_option_Mobile_Data, encoder__internet_option_Wi-Fi, encoder__used_special_discount_No, encoder__used_special_discount_Yes, encoder__offer_application_preference_No, encoder__offer_application_preference_Yes, encoder__past_complaint_No, encoder__past_complaint_Yes, encoder__complaint_status_No Information Available, encoder__complaint_status_Not Applicable, encoder__complaint_status_Solved, encoder__complaint_status_Solved in Follow-up, encoder__complaint_status_Unsolved, encoder__last_visit_time_of_day_Afternoon, encoder__last_visit_time_of_day_Evening, encoder__last_visit_time_of_day_Morning, encoder__last_visit_time_of_day_Night, encoder__last_visit_AMPM_AM, encoder__last_visit_AMPM_PM, encoder__joining_day_name_Friday, encoder__joining_day_name_Monday, encoder__joining_day_name_Saturday, encoder__joining_day_name_Sunday, encoder__joining_day_name_Thursday, encoder__joining_day_name_Tuesday, encoder__joining_day_name_Wednesday, encoder__gender+region_category_FCity, encoder__gender+region_category_FTown, encoder__gender+region_category_FVillage, encoder__gender+region_category_MCity, encoder__gender+region_category_MTown, encoder__gender+region_category_MVillage, encoder__gender+region_category_UnknownCity, encoder__gender+region_category_UnknownTown, encoder__gender+region_category_UnknownVillage, encoder__gender+membership_category_FBasic Membership, encoder__gender+membership_category_FGold Membership, encoder__gender+membership_category_FNo Membership, encoder__gender+membership_category_FPlatinum Membership, encoder__gender+membership_category_FPremium Membership, encoder__gender+membership_category_FSilver Membership, encoder__gender+membership_category_MBasic Membership, encoder__gender+membership_category_MGold Membership, encoder__gender+membership_category_MNo Membership, encoder__gender+membership_category_MPlatinum Membership, encoder__gender+membership_category_MPremium Membership, encoder__gender+membership_category_MSilver Membership, encoder__gender+membership_category_UnknownBasic Membership, encoder__gender+membership_category_UnknownGold Membership, encoder__gender+membership_category_UnknownNo Membership, encoder__gender+membership_category_UnknownPlatinum Membership, encoder__gender+membership_category_UnknownPremium Membership, encoder__gender+membership_category_UnknownSilver Membership, encoder__gender+joined_through_referral_FNo, encoder__gender+joined_through_referral_FYes, encoder__gender+joined_through_referral_MNo, encoder__gender+joined_through_referral_MYes, encoder__gender+joined_through_referral_UnknownNo, encoder__gender+joined_through_referral_UnknownYes, encoder__gender+preferred_offer_types_FCredit/Debit Card Offers, encoder__gender+preferred_offer_types_FGift Vouchers/Coupons, encoder__gender+preferred_offer_types_FWithout Offers, encoder__gender+preferred_offer_types_MCredit/Debit Card Offers, encoder__gender+preferred_offer_types_MGift Vouchers/Coupons, encoder__gender+preferred_offer_types_MWithout Offers, encoder__gender+preferred_offer_types_UnknownCredit/Debit Card Offers, encoder__gender+preferred_offer_types_UnknownGift Vouchers/Coupons, encoder__gender+preferred_offer_types_UnknownWithout Offers, encoder__gender+medium_of_operation_FBoth, encoder__gender+medium_of_operation_FDesktop, encoder__gender+medium_of_operation_FSmartphone, encoder__gender+medium_of_operation_MBoth, encoder__gender+medium_of_operation_MDesktop ...
# Index: []
#
# [0 rows x 1468 columns]

# %%
X_train_preprocessed['remainder__membership_category'].value_counts()
# Out:
# remainder__membership_category
# 0.0    5956
# 1.0    5953
# 3.0    5253
# 2.0    4702
# 5.0    3432
# 4.0    3367
# Name: count, dtype: int64

# %% [markdown]
# #### Feature selection & Importance

# %%
y_train.unique()
# Out:
# array([5., 3., 1., 2., 4.])

# %%
# target labels (y_train) starts from '1': [1, 2, 3, 4, 5], 
# but XGBoost expects them to start from 0, like [0, 1, 2, 3, 4].
xgb_clf = XGBClassifier(random_state=42).fit(X_train_preprocessed, y_train-1)
# don't forget to add one in the prediction time:
# y_pred = xgb_clf.predict(X_test_preprocessed) + 1

# %%
pd.set_option('display.max_rows', None)
importances = xgb_clf.feature_importances_
feature_names = X_train_preprocessed.columns
feature_importance_df = pd.DataFrame({'feature':feature_names, 'importance':importances})
feature_importance_df['importance'] = feature_importance_df['importance'].round(5)
feature_importance_df = feature_importance_df.sort_values('importance', ascending=False).reset_index()
feature_importance_df['cumulative_importance'] = feature_importance_df['importance'].cumsum()
feature_importance_df
# Out:
#       index                                            feature  importance  \
# 0      1464                     remainder__membership_category     0.08413
# 1      1465                                remainder__feedback     0.07429
# 2      1459                           scaler__points_in_wallet     0.01247
# 3       464  encoder__membership_category+complaint_status_...     0.00229
# 4       328  encoder__region_category+joining_day_name_City...     0.00220
# 5      1331  encoder__feedback+last_visit_AMPM_Poor Product...     0.00193
# 6       378  encoder__membership_category+medium_of_operati...     0.00189
# 7       896  encoder__medium_of_operation+joining_day_name_...     0.00182
# 8       267  encoder__region_category+complaint_status_City...     0.00152
# 9       935  encoder__internet_option+complaint_status_Fibe...     0.00139
# 10      520  encoder__membership_category+feedback_Silver M...     0.00136
# 11     1118  encoder__offer_application_preference+joining_...     0.00135
# 12       43           encoder__gender+region_category_FVillage     0.00135
# 13     1005  encoder__internet_option+joining_day_name_Wi-F...     0.00133
# 14     1356  encoder__feedback+joining_day_name_Poor Custom...     0.00132
# 15     1179  encoder__past_complaint+joining_day_name_YesWe...     0.00131
# 16     1446  encoder__last_visit_AMPM+joining_day_name_AMWe...     0.00131
# 17      124  encoder__gender+complaint_status_MNo Informati...     0.00130
# 18      683  encoder__joined_through_referral+joining_day_n...     0.00129
# 19     1277  encoder__complaint_status+joining_day_name_Sol...     0.00128
# 20      431  encoder__membership_category+offer_application...     0.00127
# 21     1181  encoder__complaint_status+feedback_No Informat...     0.00126
# 22       52  encoder__gender+membership_category_FNo Member...     0.00126
# 23      260  encoder__region_category+offer_application_pre...     0.00125
# 24     1399  encoder__feedback+joining_day_name_Too many ad...     0.00124
# 25     1366  encoder__feedback+joining_day_name_Poor Websit...     0.00124
# 26      854  encoder__medium_of_operation+feedback_BothToo ...     0.00124
# 27     1088  encoder__offer_application_preference+feedback...     0.00123
# 28      620  encoder__joined_through_referral+internet_opti...     0.00122
# 29      656  encoder__joined_through_referral+feedback_YesP...     0.00122
# 30     1420  encoder__last_visit_time_of_day+joining_day_na...     0.00121
# 31      883  encoder__medium_of_operation+last_visit_time_o...     0.00120
# 32     1066  encoder__used_special_discount+joining_day_nam...     0.00120
# 33     1198  encoder__complaint_status+feedback_Solved in F...     0.00120
# 34      229  encoder__region_category+preferred_offer_types...     0.00120
# 35      752  encoder__preferred_offer_types+feedback_Gift V...     0.00120
# 36     1184  encoder__complaint_status+feedback_No Informat...     0.00119
# 37      336  encoder__region_category+joining_day_name_Town...     0.00119
# 38      600  encoder__membership_category+joining_day_name_...     0.00119
# 39      348  encoder__membership_category+joined_through_re...     0.00118
# 40     1453  encoder__last_visit_AMPM+joining_day_name_PMWe...     0.00118
# 41      798  encoder__preferred_offer_types+joining_day_nam...     0.00117
# 42      450  encoder__membership_category+complaint_status_...     0.00117
# 43     1039  encoder__used_special_discount+feedback_YesPoo...     0.00117
# 44     1002  encoder__internet_option+joining_day_name_Mobi...     0.00115
# 45      859  encoder__medium_of_operation+feedback_DesktopP...     0.00115
# 46      436  encoder__membership_category+offer_application...     0.00114
# 47      653  encoder__joined_through_referral+feedback_YesN...     0.00114
# 48      688  encoder__preferred_offer_types+medium_of_opera...     0.00113
# 49     1290  encoder__feedback+last_visit_time_of_day_No re...     0.00113
# 50      724  encoder__preferred_offer_types+complaint_statu...     0.00113
# 51     1423  encoder__last_visit_time_of_day+joining_day_na...     0.00112
# 52     1364  encoder__feedback+joining_day_name_Poor Produc...     0.00112
# 53      565  encoder__membership_category+joining_day_name_...     0.00112
# 54      551  encoder__membership_category+last_visit_AMPM_B...     0.00112
# 55     1027  encoder__used_special_discount+complaint_statu...     0.00112
# 56     1148   encoder__past_complaint+feedback_YesPoor Website     0.00112
# 57      636  encoder__joined_through_referral+complaint_sta...     0.00111
# 58      302  encoder__region_category+feedback_VillagePoor ...     0.00111
# 59     1161  encoder__past_complaint+last_visit_time_of_day...     0.00111
# 60     1216  encoder__complaint_status+feedback_UnsolvedNo ...     0.00110
# 61      455  encoder__membership_category+complaint_status_...     0.00110
# 62      550  encoder__membership_category+last_visit_AMPM_B...     0.00109
# 63     1116  encoder__offer_application_preference+last_vis...     0.00109
# 64      546  encoder__membership_category+last_visit_time_o...     0.00109
# 65     1415  encoder__last_visit_time_of_day+joining_day_na...     0.00109
# 66      573  encoder__membership_category+joining_day_name_...     0.00108
# 67      734  encoder__preferred_offer_types+complaint_statu...     0.00108
# 68      938  encoder__internet_option+complaint_status_Mobi...     0.00107
# 69     1295  encoder__feedback+last_visit_time_of_day_Poor ...     0.00107
# 70     1008  encoder__internet_option+joining_day_name_Wi-F...     0.00107
# 71      900  encoder__medium_of_operation+joining_day_name_...     0.00106
# 72     1210  encoder__complaint_status+feedback_SolvedPoor ...     0.00106
# 73      645  encoder__joined_through_referral+feedback_NoPo...     0.00106
# 74      847  encoder__medium_of_operation+feedback_BothNo r...     0.00105
# 75      484  encoder__membership_category+feedback_Basic Me...     0.00105
# 76      964  encoder__internet_option+feedback_Wi-FiNo reas...     0.00105
# 77      326  encoder__region_category+last_visit_AMPM_Villa...     0.00105
# 78      728  encoder__preferred_offer_types+complaint_statu...     0.00105
# 79      768  encoder__preferred_offer_types+last_visit_time...     0.00105
# 80      462  encoder__membership_category+complaint_status_...     0.00105
# 81      749  encoder__preferred_offer_types+feedback_Gift V...     0.00104
# 82      121           encoder__gender+complaint_status_FSolved     0.00104
# 83      867  encoder__medium_of_operation+feedback_Smartpho...     0.00104
# 84      753  encoder__preferred_offer_types+feedback_Gift V...     0.00104
# 85     1103  encoder__offer_application_preference+feedback...     0.00104
# 86      748  encoder__preferred_offer_types+feedback_Gift V...     0.00103
# 87      962  encoder__internet_option+feedback_Mobile_DataT...     0.00103
# 88     1086  encoder__offer_application_preference+complain...     0.00103
# 89      771  encoder__preferred_offer_types+last_visit_time...     0.00103
# 90     1205  encoder__complaint_status+feedback_Solved in F...     0.00102
# 91      242  encoder__region_category+internet_option_CityW...     0.00102
# 92     1416  encoder__last_visit_time_of_day+joining_day_na...     0.00102
# 93     1137  encoder__past_complaint+feedback_NoPoor Custom...     0.00101
# 94     1451  encoder__last_visit_AMPM+joining_day_name_PMTh...     0.00101
# 95      380  encoder__membership_category+medium_of_operati...     0.00101
# 96      402  encoder__membership_category+internet_option_N...     0.00101
# 97      579  encoder__membership_category+joining_day_name_...     0.00101
# 98      139    encoder__gender+feedback_FQuality Customer Care     0.00101
# 99      294  encoder__region_category+feedback_TownPoor Web...     0.00100
# 100     959  encoder__internet_option+feedback_Mobile_DataP...     0.00100
# 101    1297  encoder__feedback+last_visit_time_of_day_Poor ...     0.00100
# 102     777  encoder__preferred_offer_types+last_visit_time...     0.00100
# 103     737  encoder__preferred_offer_types+complaint_statu...     0.00099
# 104     375  encoder__membership_category+preferred_offer_t...     0.00099
# 105     137             encoder__gender+feedback_FPoor Website     0.00098
# 106    1326  encoder__feedback+last_visit_AMPM_No reason sp...     0.00098
# 107     429  encoder__membership_category+offer_application...     0.00098
# 108    1369  encoder__feedback+joining_day_name_Poor Websit...     0.00098
# 109    1146  encoder__past_complaint+feedback_YesPoor Custo...     0.00098
# 110      58  encoder__gender+membership_category_MNo Member...     0.00098
# 111     568  encoder__membership_category+joining_day_name_...     0.00097
# 112      42              encoder__gender+region_category_FTown     0.00097
# 113     943  encoder__internet_option+complaint_status_Wi-F...     0.00097
# 114    1321  encoder__feedback+last_visit_time_of_day_Too m...     0.00096
# 115     376  encoder__membership_category+preferred_offer_t...     0.00096
# 116    1063  encoder__used_special_discount+joining_day_nam...     0.00096
# 117     676  encoder__joined_through_referral+joining_day_n...     0.00096
# 118     857  encoder__medium_of_operation+feedback_DesktopP...     0.00096
# 119    1053  encoder__used_special_discount+last_visit_time...     0.00096
# 120     963  encoder__internet_option+feedback_Mobile_DataU...     0.00096
# 121     933  encoder__internet_option+complaint_status_Fibe...     0.00096
# 122    1180  encoder__complaint_status+feedback_No Informat...     0.00096
# 123     291  encoder__region_category+feedback_TownNo reaso...     0.00096
# 124     779  encoder__preferred_offer_types+last_visit_AMPM...     0.00095
# 125     419  encoder__membership_category+used_special_disc...     0.00095
# 126     757  encoder__preferred_offer_types+feedback_Withou...     0.00095
# 127     639  encoder__joined_through_referral+complaint_sta...     0.00095
# 128     478  encoder__membership_category+complaint_status_...     0.00095
# 129     863  encoder__medium_of_operation+feedback_DesktopT...     0.00095
# 130     355  encoder__membership_category+joined_through_re...     0.00095
# 131     534  encoder__membership_category+last_visit_time_o...     0.00095
# 132    1344  encoder__feedback+joining_day_name_No reason s...     0.00095
# 133    1349  encoder__feedback+joining_day_name_No reason s...     0.00095
# 134    1120  encoder__offer_application_preference+joining_...     0.00095
# 135     185           encoder__gender+joining_day_name_MMonday     0.00094
# 136    1239  encoder__complaint_status+last_visit_time_of_d...     0.00094
# 137     406  encoder__membership_category+internet_option_P...     0.00094
# 138    1353  encoder__feedback+joining_day_name_Poor Custom...     0.00094
# 139     726  encoder__preferred_offer_types+complaint_statu...     0.00094
# 140     475  encoder__membership_category+complaint_status_...     0.00094
# 141    1038  encoder__used_special_discount+feedback_YesNo ...     0.00094
# 142      37                   encoder__joining_day_name_Sunday     0.00094
# 143    1441  encoder__last_visit_AMPM+joining_day_name_AMMo...     0.00094
# 144     674  encoder__joined_through_referral+joining_day_n...     0.00094
# 145     655  encoder__joined_through_referral+feedback_YesP...     0.00094
# 146     555  encoder__membership_category+last_visit_AMPM_N...     0.00094
# 147    1089  encoder__offer_application_preference+feedback...     0.00094
# 148     610  encoder__joined_through_referral+medium_of_ope...     0.00093
# 149     649  encoder__joined_through_referral+feedback_NoQu...     0.00093
# 150     710  encoder__preferred_offer_types+used_special_di...     0.00093
# 151     704  encoder__preferred_offer_types+internet_option...     0.00093
# 152     276  encoder__region_category+complaint_status_Town...     0.00093
# 153     739  encoder__preferred_offer_types+feedback_Credit...     0.00093
# 154    1122  encoder__offer_application_preference+joining_...     0.00093
# 155    1036  encoder__used_special_discount+feedback_NoToo ...     0.00093
# 156     126           encoder__gender+complaint_status_MSolved     0.00093
# 157     398  encoder__membership_category+internet_option_B...     0.00093
# 158     547  encoder__membership_category+last_visit_time_o...     0.00092
# 159     823  encoder__medium_of_operation+offer_application...     0.00092
# 160     670  encoder__joined_through_referral+last_visit_AM...     0.00092
# 161    1023  encoder__used_special_discount+complaint_statu...     0.00092
# 162     751  encoder__preferred_offer_types+feedback_Gift V...     0.00092
# 163     179         encoder__gender+joining_day_name_FSaturday     0.00092
# 164    1098  encoder__offer_application_preference+feedback...     0.00092
# 165    1270  encoder__complaint_status+joining_day_name_Sol...     0.00092
# 166     396  encoder__membership_category+internet_option_B...     0.00091
# 167     301  encoder__region_category+feedback_VillagePoor ...     0.00091
# 168     403  encoder__membership_category+internet_option_N...     0.00091
# 169     882  encoder__medium_of_operation+last_visit_time_o...     0.00091
# 170     767  encoder__preferred_offer_types+last_visit_time...     0.00091
# 171     662  encoder__joined_through_referral+last_visit_ti...     0.00091
# 172    1347  encoder__feedback+joining_day_name_No reason s...     0.00091
# 173    1041  encoder__used_special_discount+feedback_YesPoo...     0.00091
# 174    1340   encoder__feedback+last_visit_AMPM_Too many adsAM     0.00091
# 175     584  encoder__membership_category+joining_day_name_...     0.00091
# 176     760  encoder__preferred_offer_types+feedback_Withou...     0.00091
# 177     736  encoder__preferred_offer_types+complaint_statu...     0.00091
# 178    1341   encoder__feedback+last_visit_AMPM_Too many adsPM     0.00090
# 179     209  encoder__region_category+membership_category_T...     0.00090
# 180    1300  encoder__feedback+last_visit_time_of_day_Poor ...     0.00090
# 181     496  encoder__membership_category+feedback_No Membe...     0.00090
# 182     796  encoder__preferred_offer_types+joining_day_nam...     0.00090
# 183     430  encoder__membership_category+offer_application...     0.00090
# 184     842  encoder__medium_of_operation+complaint_status_...     0.00090
# 185     408  encoder__membership_category+internet_option_P...     0.00090
# 186    1113  encoder__offer_application_preference+last_vis...     0.00090
# 187    1174  encoder__past_complaint+joining_day_name_YesMo...     0.00090
# 188    1160  encoder__past_complaint+last_visit_time_of_day...     0.00090
# 189     877  encoder__medium_of_operation+last_visit_time_o...     0.00089
# 190     837  encoder__medium_of_operation+complaint_status_...     0.00089
# 191     758  encoder__preferred_offer_types+feedback_Withou...     0.00089
# 192    1322  encoder__feedback+last_visit_time_of_day_User ...     0.00089
# 193     581  encoder__membership_category+joining_day_name_...     0.00089
# 194     971  encoder__internet_option+feedback_Wi-FiToo man...     0.00089
# 195     527  encoder__membership_category+last_visit_time_o...     0.00089
# 196     349  encoder__membership_category+joined_through_re...     0.00089
# 197    1311  encoder__feedback+last_visit_time_of_day_Quali...     0.00089
# 198    1435  encoder__last_visit_time_of_day+joining_day_na...     0.00089
# 199     785  encoder__preferred_offer_types+joining_day_nam...     0.00089
# 200     644  encoder__joined_through_referral+feedback_NoNo...     0.00089
# 201     298  encoder__region_category+feedback_TownToo many...     0.00088
# 202     740  encoder__preferred_offer_types+feedback_Credit...     0.00088
# 203     535  encoder__membership_category+last_visit_time_o...     0.00088
# 204     668  encoder__joined_through_referral+last_visit_ti...     0.00088
# 205    1259  encoder__complaint_status+joining_day_name_No ...     0.00088
# 206    1350  encoder__feedback+joining_day_name_No reason s...     0.00088
# 207     240  encoder__region_category+internet_option_CityF...     0.00088
# 208     358  encoder__membership_category+joined_through_re...     0.00088
# 209     786  encoder__preferred_offer_types+joining_day_nam...     0.00088
# 210     680  encoder__joined_through_referral+joining_day_n...     0.00088
# 211     177           encoder__gender+joining_day_name_FFriday     0.00088
# 212      50  encoder__gender+membership_category_FBasic Mem...     0.00087
# 213     791  encoder__preferred_offer_types+joining_day_nam...     0.00087
# 214     905  encoder__medium_of_operation+joining_day_name_...     0.00087
# 215     386  encoder__membership_category+medium_of_operati...     0.00087
# 216    1320  encoder__feedback+last_visit_time_of_day_Too m...     0.00087
# 217    1217  encoder__complaint_status+feedback_UnsolvedPoo...     0.00087
# 218     554  encoder__membership_category+last_visit_AMPM_N...     0.00087
# 219     198  encoder__region_category+membership_category_C...     0.00087
# 220     512  encoder__membership_category+feedback_Premium ...     0.00087
# 221     487  encoder__membership_category+feedback_Gold Mem...     0.00087
# 222     577  encoder__membership_category+joining_day_name_...     0.00086
# 223     384  encoder__membership_category+medium_of_operati...     0.00086
# 224     339  encoder__region_category+joining_day_name_Town...     0.00086
# 225     809  encoder__medium_of_operation+internet_option_D...     0.00086
# 226     732  encoder__preferred_offer_types+complaint_statu...     0.00085
# 227     122  encoder__gender+complaint_status_FSolved in Fo...     0.00085
# 228    1357  encoder__feedback+joining_day_name_Poor Custom...     0.00085
# 229     968  encoder__internet_option+feedback_Wi-FiProduct...     0.00085
# 230     517  encoder__membership_category+feedback_Silver M...     0.00085
# 231     820  encoder__medium_of_operation+offer_application...     0.00085
# 232    1087  encoder__offer_application_preference+feedback...     0.00085
# 233     705  encoder__preferred_offer_types+internet_option...     0.00085
# 234     494  encoder__membership_category+feedback_No Membe...     0.00085
# 235     293  encoder__region_category+feedback_TownPoor Pro...     0.00085
# 236     331  encoder__region_category+joining_day_name_City...     0.00085
# 237     875  encoder__medium_of_operation+last_visit_time_o...     0.00084
# 238     270  encoder__region_category+complaint_status_City...     0.00084
# 239     626  encoder__joined_through_referral+offer_applica...     0.00084
# 240     307  encoder__region_category+feedback_VillageToo m...     0.00084
# 241     397  encoder__membership_category+internet_option_B...     0.00084
# 242     845  encoder__medium_of_operation+complaint_status_...     0.00084
# 243     848  encoder__medium_of_operation+feedback_BothPoor...     0.00084
# 244      23  encoder__complaint_status_No Information Avail...     0.00084
# 245     377  encoder__membership_category+preferred_offer_t...     0.00083
# 246    1274  encoder__complaint_status+joining_day_name_Sol...     0.00083
# 247     145     encoder__gender+feedback_MPoor Product Quality     0.00083
# 248     898  encoder__medium_of_operation+joining_day_name_...     0.00083
# 249     563  encoder__membership_category+joining_day_name_...     0.00083
# 250     183        encoder__gender+joining_day_name_FWednesday     0.00083
# 251    1084  encoder__offer_application_preference+complain...     0.00083
# 252     368  encoder__membership_category+preferred_offer_t...     0.00083
# 253    1251  encoder__complaint_status+last_visit_AMPM_Solv...     0.00083
# 254     101          encoder__gender+used_special_discount_FNo     0.00083
# 255     975  encoder__internet_option+last_visit_time_of_da...     0.00083
# 256     261     encoder__region_category+past_complaint_CityNo     0.00083
# 257     741  encoder__preferred_offer_types+feedback_Credit...     0.00083
# 258    1301  encoder__feedback+last_visit_time_of_day_Poor ...     0.00083
# 259     746  encoder__preferred_offer_types+feedback_Credit...     0.00083
# 260    1414  encoder__last_visit_time_of_day+joining_day_na...     0.00083
# 261    1413  encoder__last_visit_time_of_day+joining_day_na...     0.00083
# 262     232  encoder__region_category+medium_of_operation_C...     0.00083
# 263    1443  encoder__last_visit_AMPM+joining_day_name_AMSu...     0.00083
# 264      75  encoder__gender+preferred_offer_types_FGift Vo...     0.00083
# 265     647  encoder__joined_through_referral+feedback_NoPo...     0.00082
# 266     592  encoder__membership_category+joining_day_name_...     0.00082
# 267     981  encoder__internet_option+last_visit_time_of_da...     0.00082
# 268    1155  encoder__past_complaint+last_visit_time_of_day...     0.00082
# 269     206  encoder__region_category+membership_category_T...     0.00082
# 270     329  encoder__region_category+joining_day_name_City...     0.00082
# 271    1147  encoder__past_complaint+feedback_YesPoor Produ...     0.00082
# 272    1003  encoder__internet_option+joining_day_name_Mobi...     0.00082
# 273     220  encoder__region_category+joined_through_referr...     0.00082
# 274     908  encoder__medium_of_operation+joining_day_name_...     0.00082
# 275     128         encoder__gender+complaint_status_MUnsolved     0.00082
# 276     800  encoder__preferred_offer_types+joining_day_nam...     0.00082
# 277     681  encoder__joined_through_referral+joining_day_n...     0.00082
# 278    1127  encoder__offer_application_preference+joining_...     0.00082
# 279    1208  encoder__complaint_status+feedback_SolvedPoor ...     0.00082
# 280    1450  encoder__last_visit_AMPM+joining_day_name_PMSu...     0.00082
# 281    1452  encoder__last_visit_AMPM+joining_day_name_PMTu...     0.00082
# 282     187           encoder__gender+joining_day_name_MSunday     0.00082
# 283    1424  encoder__last_visit_time_of_day+joining_day_na...     0.00082
# 284    1303  encoder__feedback+last_visit_time_of_day_Poor ...     0.00082
# 285     346  encoder__region_category+joining_day_name_Vill...     0.00081
# 286     989   encoder__internet_option+last_visit_AMPM_Wi-FiAM     0.00081
# 287     795  encoder__preferred_offer_types+joining_day_nam...     0.00081
# 288      60  encoder__gender+membership_category_MPremium M...     0.00081
# 289     628  encoder__joined_through_referral+offer_applica...     0.00081
# 290     922  encoder__internet_option+offer_application_pre...     0.00081
# 291     379  encoder__membership_category+medium_of_operati...     0.00081
# 292     634  encoder__joined_through_referral+complaint_sta...     0.00081
# 293     578  encoder__membership_category+joining_day_name_...     0.00081
# 294    1422  encoder__last_visit_time_of_day+joining_day_na...     0.00081
# 295    1028  encoder__used_special_discount+complaint_statu...     0.00081
# 296     161    encoder__gender+last_visit_time_of_day_FMorning     0.00081
# 297    1257  encoder__complaint_status+joining_day_name_No ...     0.00081
# 298    1031  encoder__used_special_discount+feedback_NoPoor...     0.00081
# 299    1064  encoder__used_special_discount+joining_day_nam...     0.00081
# 300    1145  encoder__past_complaint+feedback_YesNo reason ...     0.00081
# 301     292  encoder__region_category+feedback_TownPoor Cus...     0.00081
# 302     290  encoder__region_category+feedback_CityUser Fri...     0.00081
# 303    1200  encoder__complaint_status+feedback_Solved in F...     0.00080
# 304     707  encoder__preferred_offer_types+used_special_di...     0.00080
# 305     226  encoder__region_category+preferred_offer_types...     0.00080
# 306    1283  encoder__complaint_status+joining_day_name_Uns...     0.00080
# 307     537  encoder__membership_category+last_visit_time_o...     0.00080
# 308     980  encoder__internet_option+last_visit_time_of_da...     0.00080
# 309    1362  encoder__feedback+joining_day_name_Poor Produc...     0.00080
# 310     360  encoder__membership_category+preferred_offer_t...     0.00080
# 311     966  encoder__internet_option+feedback_Wi-FiPoor Pr...     0.00080
# 312     264    encoder__region_category+past_complaint_TownYes     0.00080
# 313    1448  encoder__last_visit_AMPM+joining_day_name_PMMo...     0.00080
# 314    1336  encoder__feedback+last_visit_AMPM_Quality Cust...     0.00080
# 315     570  encoder__membership_category+joining_day_name_...     0.00080
# 316    1426  encoder__last_visit_time_of_day+joining_day_na...     0.00080
# 317     912  encoder__medium_of_operation+joining_day_name_...     0.00079
# 318     426  encoder__membership_category+offer_application...     0.00079
# 319     714  encoder__preferred_offer_types+offer_applicati...     0.00079
# 320     928  encoder__internet_option+past_complaint_Mobile...     0.00079
# 321     489  encoder__membership_category+feedback_Gold Mem...     0.00079
# 322     733  encoder__preferred_offer_types+complaint_statu...     0.00079
# 323     950  encoder__internet_option+feedback_Fiber_OpticP...     0.00079
# 324     806  encoder__medium_of_operation+internet_option_B...     0.00079
# 325    1085  encoder__offer_application_preference+complain...     0.00079
# 326    1363  encoder__feedback+joining_day_name_Poor Produc...     0.00079
# 327     973  encoder__internet_option+last_visit_time_of_da...     0.00079
# 328     608  encoder__joined_through_referral+preferred_off...     0.00079
# 329    1437  encoder__last_visit_time_of_day+joining_day_na...     0.00079
# 330     793  encoder__preferred_offer_types+joining_day_nam...     0.00079
# 331     731  encoder__preferred_offer_types+complaint_statu...     0.00079
# 332     993  encoder__internet_option+joining_day_name_Fibe...     0.00079
# 333     420  encoder__membership_category+used_special_disc...     0.00078
# 334     723  encoder__preferred_offer_types+past_complaint_...     0.00078
# 335    1394  encoder__feedback+joining_day_name_Too many ad...     0.00078
# 336     687  encoder__joined_through_referral+joining_day_n...     0.00078
# 337    1068  encoder__used_special_discount+joining_day_nam...     0.00078
# 338     712  encoder__preferred_offer_types+offer_applicati...     0.00078
# 339     457  encoder__membership_category+complaint_status_...     0.00078
# 340     539  encoder__membership_category+last_visit_time_o...     0.00078
# 341     947  encoder__internet_option+feedback_Fiber_OpticP...     0.00078
# 342     906  encoder__medium_of_operation+joining_day_name_...     0.00077
# 343    1302  encoder__feedback+last_visit_time_of_day_Poor ...     0.00077
# 344    1431  encoder__last_visit_time_of_day+joining_day_na...     0.00077
# 345     437  encoder__membership_category+offer_application...     0.00077
# 346     742  encoder__preferred_offer_types+feedback_Credit...     0.00077
# 347    1130  encoder__offer_application_preference+joining_...     0.00077
# 348    1109  encoder__offer_application_preference+last_vis...     0.00077
# 349     691  encoder__preferred_offer_types+medium_of_opera...     0.00077
# 350     650  encoder__joined_through_referral+feedback_NoRe...     0.00077
# 351     637  encoder__joined_through_referral+complaint_sta...     0.00077
# 352    1289  encoder__complaint_status+joining_day_name_Uns...     0.00077
# 353     134      encoder__gender+feedback_FNo reason specified     0.00077
# 354    1244  encoder__complaint_status+last_visit_time_of_d...     0.00077
# 355      38                 encoder__joining_day_name_Thursday     0.00077
# 356     526  encoder__membership_category+last_visit_time_o...     0.00076
# 357    1207  encoder__complaint_status+feedback_SolvedNo re...     0.00076
# 358     458  encoder__membership_category+complaint_status_...     0.00076
# 359     808  encoder__medium_of_operation+internet_option_D...     0.00076
# 360    1090  encoder__offer_application_preference+feedback...     0.00076
# 361     839  encoder__medium_of_operation+complaint_status_...     0.00076
# 362     684  encoder__joined_through_referral+joining_day_n...     0.00076
# 363     333  encoder__region_category+joining_day_name_City...     0.00076
# 364     872  encoder__medium_of_operation+feedback_Smartpho...     0.00076
# 365     903  encoder__medium_of_operation+joining_day_name_...     0.00076
# 366     692  encoder__preferred_offer_types+medium_of_opera...     0.00076
# 367     946  encoder__internet_option+feedback_Fiber_OpticN...     0.00076
# 368     485  encoder__membership_category+feedback_Gold Mem...     0.00076
# 369     856  encoder__medium_of_operation+feedback_DesktopN...     0.00076
# 370    1112  encoder__offer_application_preference+last_vis...     0.00076
# 371    1334  encoder__feedback+last_visit_AMPM_Products alw...     0.00076
# 372     560  encoder__membership_category+last_visit_AMPM_S...     0.00076
# 373     528  encoder__membership_category+last_visit_time_o...     0.00076
# 374     244  encoder__region_category+internet_option_TownM...     0.00076
# 375    1199  encoder__complaint_status+feedback_Solved in F...     0.00076
# 376     231  encoder__region_category+medium_of_operation_C...     0.00075
# 377    1410  encoder__last_visit_time_of_day+last_visit_AMP...     0.00075
# 378    1162       encoder__past_complaint+last_visit_AMPM_NoAM     0.00075
# 379    1007  encoder__internet_option+joining_day_name_Wi-F...     0.00075
# 380    1393  encoder__feedback+joining_day_name_Too many ad...     0.00075
# 381    1299  encoder__feedback+last_visit_time_of_day_Poor ...     0.00075
# 382    1124  encoder__offer_application_preference+joining_...     0.00075
# 383     957  encoder__internet_option+feedback_Mobile_DataP...     0.00075
# 384     929    encoder__internet_option+past_complaint_Wi-FiNo     0.00075
# 385    1082  encoder__offer_application_preference+complain...     0.00075
# 386     750  encoder__preferred_offer_types+feedback_Gift V...     0.00075
# 387     925  encoder__internet_option+past_complaint_Fiber_...     0.00075
# 388     923  encoder__internet_option+offer_application_pre...     0.00075
# 389    1076  encoder__offer_application_preference+past_com...     0.00075
# 390     811  encoder__medium_of_operation+internet_option_S...     0.00075
# 391    1330  encoder__feedback+last_visit_AMPM_Poor Product...     0.00075
# 392     638  encoder__joined_through_referral+complaint_sta...     0.00075
# 393     143      encoder__gender+feedback_MNo reason specified     0.00075
# 394     540  encoder__membership_category+last_visit_time_o...     0.00075
# 395    1069  encoder__used_special_discount+joining_day_nam...     0.00075
# 396     887  encoder__medium_of_operation+last_visit_AMPM_B...     0.00075
# 397    1136  encoder__past_complaint+feedback_NoNo reason s...     0.00075
# 398     669  encoder__joined_through_referral+last_visit_ti...     0.00075
# 399     774  encoder__preferred_offer_types+last_visit_time...     0.00075
# 400      11                  encoder__medium_of_operation_Both     0.00074
# 401     716  encoder__preferred_offer_types+offer_applicati...     0.00074
# 402     821  encoder__medium_of_operation+offer_application...     0.00074
# 403    1296  encoder__feedback+last_visit_time_of_day_Poor ...     0.00074
# 404     790  encoder__preferred_offer_types+joining_day_nam...     0.00074
# 405     529  encoder__membership_category+last_visit_time_o...     0.00074
# 406     983  encoder__internet_option+last_visit_time_of_da...     0.00074
# 407     362  encoder__membership_category+preferred_offer_t...     0.00074
# 408    1439  encoder__last_visit_time_of_day+joining_day_na...     0.00074
# 409     789  encoder__preferred_offer_types+joining_day_nam...     0.00074
# 410     182          encoder__gender+joining_day_name_FTuesday     0.00074
# 411     114                encoder__gender+past_complaint_FYes     0.00074
# 412    1079  encoder__offer_application_preference+complain...     0.00074
# 413     321    encoder__region_category+last_visit_AMPM_CityAM     0.00074
# 414    1165      encoder__past_complaint+last_visit_AMPM_YesPM     0.00074
# 415     253  encoder__region_category+used_special_discount...     0.00074
# 416     289  encoder__region_category+feedback_CityToo many...     0.00074
# 417     761  encoder__preferred_offer_types+feedback_Withou...     0.00073
# 418    1034  encoder__used_special_discount+feedback_NoQual...     0.00073
# 419     597  encoder__membership_category+joining_day_name_...     0.00073
# 420    1298  encoder__feedback+last_visit_time_of_day_Poor ...     0.00073
# 421     792  encoder__preferred_offer_types+joining_day_nam...     0.00073
# 422     643  encoder__joined_through_referral+complaint_sta...     0.00073
# 423     953  encoder__internet_option+feedback_Fiber_OpticT...     0.00073
# 424     660  encoder__joined_through_referral+feedback_YesT...     0.00073
# 425     665  encoder__joined_through_referral+last_visit_ti...     0.00073
# 426     404  encoder__membership_category+internet_option_N...     0.00073
# 427     249  encoder__region_category+used_special_discount...     0.00073
# 428     703  encoder__preferred_offer_types+internet_option...     0.00073
# 429     160    encoder__gender+last_visit_time_of_day_FEvening     0.00073
# 430    1361  encoder__feedback+joining_day_name_Poor Produc...     0.00073
# 431     783  encoder__preferred_offer_types+last_visit_AMPM...     0.00073
# 432     697  encoder__preferred_offer_types+internet_option...     0.00073
# 433    1108  encoder__offer_application_preference+last_vis...     0.00073
# 434     205  encoder__region_category+membership_category_T...     0.00073
# 435     256  encoder__region_category+offer_application_pre...     0.00073
# 436     383  encoder__membership_category+medium_of_operati...     0.00073
# 437     678  encoder__joined_through_referral+joining_day_n...     0.00073
# 438     265  encoder__region_category+past_complaint_VillageNo     0.00073
# 439    1396  encoder__feedback+joining_day_name_Too many ad...     0.00073
# 440     204  encoder__region_category+membership_category_T...     0.00073
# 441    1447  encoder__last_visit_AMPM+joining_day_name_PMFr...     0.00073
# 442     780  encoder__preferred_offer_types+last_visit_AMPM...     0.00072
# 443    1430  encoder__last_visit_time_of_day+joining_day_na...     0.00072
# 444      70        encoder__gender+joined_through_referral_MNo     0.00072
# 445     884  encoder__medium_of_operation+last_visit_time_o...     0.00072
# 446    1292  encoder__feedback+last_visit_time_of_day_No re...     0.00072
# 447     914  encoder__internet_option+used_special_discount...     0.00072
# 448     977  encoder__internet_option+last_visit_time_of_da...     0.00072
# 449     548  encoder__membership_category+last_visit_time_o...     0.00072
# 450     332  encoder__region_category+joining_day_name_City...     0.00072
# 451    1325  encoder__feedback+last_visit_time_of_day_User ...     0.00072
# 452    1111  encoder__offer_application_preference+last_vis...     0.00072
# 453    1253  encoder__complaint_status+last_visit_AMPM_Unso...     0.00072
# 454     609  encoder__joined_through_referral+preferred_off...     0.00072
# 455      94             encoder__gender+internet_option_FWi-Fi     0.00072
# 456     885  encoder__medium_of_operation+last_visit_time_o...     0.00072
# 457     881  encoder__medium_of_operation+last_visit_time_o...     0.00072
# 458     566  encoder__membership_category+joining_day_name_...     0.00072
# 459     141             encoder__gender+feedback_FToo many ads     0.00072
# 460     604  encoder__joined_through_referral+preferred_off...     0.00071
# 461     585  encoder__membership_category+joining_day_name_...     0.00071
# 462     479  encoder__membership_category+complaint_status_...     0.00071
# 463    1225  encoder__complaint_status+last_visit_time_of_d...     0.00071
# 464    1169  encoder__past_complaint+joining_day_name_NoSunday     0.00071
# 465    1305  encoder__feedback+last_visit_time_of_day_Poor ...     0.00071
# 466    1293  encoder__feedback+last_visit_time_of_day_No re...     0.00071
# 467     690  encoder__preferred_offer_types+medium_of_opera...     0.00071
# 468    1445  encoder__last_visit_AMPM+joining_day_name_AMTu...     0.00071
# 469    1425  encoder__last_visit_time_of_day+joining_day_na...     0.00071
# 470     866  encoder__medium_of_operation+feedback_Smartpho...     0.00071
# 471     330  encoder__region_category+joining_day_name_City...     0.00071
# 472     367  encoder__membership_category+preferred_offer_t...     0.00071
# 473     258  encoder__region_category+offer_application_pre...     0.00071
# 474    1156  encoder__past_complaint+last_visit_time_of_day...     0.00071
# 475     772  encoder__preferred_offer_types+last_visit_time...     0.00071
# 476     995  encoder__internet_option+joining_day_name_Fibe...     0.00071
# 477     323    encoder__region_category+last_visit_AMPM_TownAM     0.00071
# 478     985  encoder__internet_option+last_visit_AMPM_Fiber...     0.00071
# 479     239  encoder__region_category+medium_of_operation_V...     0.00071
# 480    1129  encoder__offer_application_preference+joining_...     0.00071
# 481    1123  encoder__offer_application_preference+joining_...     0.00071
# 482     902  encoder__medium_of_operation+joining_day_name_...     0.00070
# 483     123         encoder__gender+complaint_status_FUnsolved     0.00070
# 484     830  encoder__medium_of_operation+past_complaint_Sm...     0.00070
# 485     513  encoder__membership_category+feedback_Premium ...     0.00070
# 486    1065  encoder__used_special_discount+joining_day_nam...     0.00070
# 487     870  encoder__medium_of_operation+feedback_Smartpho...     0.00070
# 488     920  encoder__internet_option+offer_application_pre...     0.00070
# 489    1043  encoder__used_special_discount+feedback_YesQua...     0.00070
# 490    1056  encoder__used_special_discount+last_visit_AMPM...     0.00070
# 491    1284  encoder__complaint_status+joining_day_name_Uns...     0.00070
# 492     144    encoder__gender+feedback_MPoor Customer Service     0.00070
# 493     605  encoder__joined_through_referral+preferred_off...     0.00070
# 494     632  encoder__joined_through_referral+past_complain...     0.00070
# 495     997  encoder__internet_option+joining_day_name_Fibe...     0.00070
# 496     149         encoder__gender+feedback_MReasonable Price     0.00070
# 497     233  encoder__region_category+medium_of_operation_C...     0.00070
# 498     234  encoder__region_category+medium_of_operation_T...     0.00070
# 499     345  encoder__region_category+joining_day_name_Vill...     0.00070
# 500     787  encoder__preferred_offer_types+joining_day_nam...     0.00070
# 501     803  encoder__preferred_offer_types+joining_day_nam...     0.00070
# 502    1258  encoder__complaint_status+joining_day_name_No ...     0.00070
# 503     952  encoder__internet_option+feedback_Fiber_OpticR...     0.00070
# 504     622  encoder__joined_through_referral+used_special_...     0.00069
# 505    1001  encoder__internet_option+joining_day_name_Mobi...     0.00069
# 506    1201  encoder__complaint_status+feedback_Solved in F...     0.00069
# 507    1006  encoder__internet_option+joining_day_name_Wi-F...     0.00069
# 508    1315  encoder__feedback+last_visit_time_of_day_Reaso...     0.00069
# 509     222  encoder__region_category+preferred_offer_types...     0.00069
# 510     759  encoder__preferred_offer_types+feedback_Withou...     0.00069
# 511     986  encoder__internet_option+last_visit_AMPM_Fiber...     0.00069
# 512     999  encoder__internet_option+joining_day_name_Mobi...     0.00069
# 513     874  encoder__medium_of_operation+last_visit_time_o...     0.00069
# 514     352  encoder__membership_category+joined_through_re...     0.00069
# 515    1138  encoder__past_complaint+feedback_NoPoor Produc...     0.00069
# 516     846  encoder__medium_of_operation+complaint_status_...     0.00069
# 517     337  encoder__region_category+joining_day_name_Town...     0.00069
# 518     927  encoder__internet_option+past_complaint_Mobile...     0.00069
# 519     416  encoder__membership_category+used_special_disc...     0.00069
# 520     829  encoder__medium_of_operation+past_complaint_De...     0.00069
# 521      56  encoder__gender+membership_category_MBasic Mem...     0.00069
# 522     994  encoder__internet_option+joining_day_name_Fibe...     0.00069
# 523    1075  encoder__offer_application_preference+past_com...     0.00069
# 524     934  encoder__internet_option+complaint_status_Fibe...     0.00068
# 525      97             encoder__gender+internet_option_MWi-Fi     0.00068
# 526     844  encoder__medium_of_operation+complaint_status_...     0.00068
# 527     878  encoder__medium_of_operation+last_visit_time_o...     0.00068
# 528    1359  encoder__feedback+joining_day_name_Poor Produc...     0.00068
# 529     868  encoder__medium_of_operation+feedback_Smartpho...     0.00068
# 530     984  encoder__internet_option+last_visit_time_of_da...     0.00068
# 531     136     encoder__gender+feedback_FPoor Product Quality     0.00068
# 532     822  encoder__medium_of_operation+offer_application...     0.00068
# 533      88    encoder__gender+medium_of_operation_MSmartphone     0.00068
# 534    1310  encoder__feedback+last_visit_time_of_day_Quali...     0.00068
# 535     443  encoder__membership_category+past_complaint_No...     0.00068
# 536    1306  encoder__feedback+last_visit_time_of_day_Produ...     0.00068
# 537    1236  encoder__complaint_status+last_visit_time_of_d...     0.00068
# 538     181         encoder__gender+joining_day_name_FThursday     0.00067
# 539    1436  encoder__last_visit_time_of_day+joining_day_na...     0.00067
# 540    1246  encoder__complaint_status+last_visit_AMPM_No I...     0.00067
# 541    1351  encoder__feedback+joining_day_name_Poor Custom...     0.00067
# 542    1275  encoder__complaint_status+joining_day_name_Sol...     0.00067
# 543    1092  encoder__offer_application_preference+feedback...     0.00067
# 544     646  encoder__joined_through_referral+feedback_NoPo...     0.00067
# 545     699  encoder__preferred_offer_types+internet_option...     0.00067
# 546     472  encoder__membership_category+complaint_status_...     0.00067
# 547    1159  encoder__past_complaint+last_visit_time_of_day...     0.00067
# 548     438  encoder__membership_category+past_complaint_Ba...     0.00067
# 549     721  encoder__preferred_offer_types+past_complaint_...     0.00067
# 550     488  encoder__membership_category+feedback_Gold Mem...     0.00067
# 551     807  encoder__medium_of_operation+internet_option_B...     0.00067
# 552     715  encoder__preferred_offer_types+offer_applicati...     0.00067
# 553     708  encoder__preferred_offer_types+used_special_di...     0.00067
# 554    1339  encoder__feedback+last_visit_AMPM_Reasonable P...     0.00067
# 555     495  encoder__membership_category+feedback_No Membe...     0.00067
# 556    1291  encoder__feedback+last_visit_time_of_day_No re...     0.00067
# 557     880  encoder__medium_of_operation+last_visit_time_o...     0.00067
# 558    1107  encoder__offer_application_preference+last_vis...     0.00067
# 559     361  encoder__membership_category+preferred_offer_t...     0.00067
# 560     255  encoder__region_category+offer_application_pre...     0.00067
# 561    1442  encoder__last_visit_AMPM+joining_day_name_AMSa...     0.00066
# 562    1212  encoder__complaint_status+feedback_SolvedQuali...     0.00066
# 563     582  encoder__membership_category+joining_day_name_...     0.00066
# 564    1260  encoder__complaint_status+joining_day_name_No ...     0.00066
# 565     919  encoder__internet_option+offer_application_pre...     0.00066
# 566     773  encoder__preferred_offer_types+last_visit_time...     0.00066
# 567     888  encoder__medium_of_operation+last_visit_AMPM_D...     0.00066
# 568     719  encoder__preferred_offer_types+past_complaint_...     0.00066
# 569    1032  encoder__used_special_discount+feedback_NoPoor...     0.00066
# 570     996  encoder__internet_option+joining_day_name_Fibe...     0.00066
# 571     976  encoder__internet_option+last_visit_time_of_da...     0.00066
# 572     816  encoder__medium_of_operation+used_special_disc...     0.00066
# 573    1074  encoder__offer_application_preference+past_com...     0.00066
# 574     606  encoder__joined_through_referral+preferred_off...     0.00066
# 575     754  encoder__preferred_offer_types+feedback_Gift V...     0.00066
# 576     717  encoder__preferred_offer_types+offer_applicati...     0.00066
# 577     575  encoder__membership_category+joining_day_name_...     0.00066
# 578     284  encoder__region_category+feedback_CityPoor Pro...     0.00066
# 579    1429  encoder__last_visit_time_of_day+joining_day_na...     0.00066
# 580     453  encoder__membership_category+complaint_status_...     0.00066
# 581     483  encoder__membership_category+feedback_Basic Me...     0.00066
# 582     439  encoder__membership_category+past_complaint_Ba...     0.00066
# 583     371  encoder__membership_category+preferred_offer_t...     0.00066
# 584     497  encoder__membership_category+feedback_No Membe...     0.00066
# 585     327  encoder__region_category+joining_day_name_City...     0.00066
# 586     212  encoder__region_category+membership_category_V...     0.00066
# 587     203  encoder__region_category+membership_category_C...     0.00066
# 588    1411  encoder__last_visit_time_of_day+last_visit_AMP...     0.00065
# 589     282  encoder__region_category+feedback_CityNo reaso...     0.00065
# 590    1224  encoder__complaint_status+feedback_UnsolvedUse...     0.00065
# 591    1062  encoder__used_special_discount+joining_day_nam...     0.00065
# 592     347  encoder__region_category+joining_day_name_Vill...     0.00065
# 593    1440  encoder__last_visit_AMPM+joining_day_name_AMFr...     0.00065
# 594     671  encoder__joined_through_referral+last_visit_AM...     0.00065
# 595     890  encoder__medium_of_operation+last_visit_AMPM_S...     0.00065
# 596     382  encoder__membership_category+medium_of_operati...     0.00065
# 597    1395  encoder__feedback+joining_day_name_Too many ad...     0.00065
# 598     955  encoder__internet_option+feedback_Mobile_DataN...     0.00065
# 599     673  encoder__joined_through_referral+last_visit_AM...     0.00065
# 600     817  encoder__medium_of_operation+used_special_disc...     0.00065
# 601     805  encoder__medium_of_operation+internet_option_B...     0.00065
# 602    1374  encoder__feedback+joining_day_name_Products al...     0.00065
# 603      76  encoder__gender+preferred_offer_types_FWithout...     0.00065
# 604     936  encoder__internet_option+complaint_status_Mobi...     0.00065
# 605      78  encoder__gender+preferred_offer_types_MGift Vo...     0.00065
# 606     571  encoder__membership_category+joining_day_name_...     0.00065
# 607    1276  encoder__complaint_status+joining_day_name_Sol...     0.00065
# 608     967  encoder__internet_option+feedback_Wi-FiPoor We...     0.00065
# 609     826  encoder__medium_of_operation+past_complaint_Bo...     0.00064
# 610     414  encoder__membership_category+used_special_disc...     0.00064
# 611     918  encoder__internet_option+used_special_discount...     0.00064
# 612     693  encoder__preferred_offer_types+medium_of_opera...     0.00064
# 613     364  encoder__membership_category+preferred_offer_t...     0.00064
# ...
# 935                0.873340
# 936                0.873840
# 937                0.874340
# 938                0.874840
# 939                0.875330
# 940                0.875820
# 941                0.876310
# 942                0.876800
# 943                0.877290
# 944                0.877780
# 945                0.878270
# 946                0.878760
# 947                0.879250
# 948                0.879740
# 949                0.880230
# 950                0.880720
# 951                0.881210
# 952                0.881700
# 953                0.882190
# 954                0.882670
# 955                0.883150
# 956                0.883630
# 957                0.884110
# 958                0.884590
# 959                0.885070
# 960                0.885550
# 961                0.886030
# 962                0.886510
# 963                0.886990
# 964                0.887470
# 965                0.887950
# 966                0.888430
# 967                0.888910
# 968                0.889390
# 969                0.889870
# 970                0.890350
# 971                0.890820
# 972                0.891290
# 973                0.891760
# 974                0.892230
# 975                0.892700
# 976                0.893170
# 977                0.893640
# 978                0.894110
# 979                0.894580
# 980                0.895050
# 981                0.895520
# 982                0.895990
# 983                0.896460
# 984                0.896920
# 985                0.897380
# 986                0.897840
# 987                0.898300
# 988                0.898760
# 989                0.899220
# 990                0.899680
# 991                0.900140
# 992                0.900600
# 993                0.901060
# 994                0.901520
# 995                0.901981
# 996                0.902441
# 997                0.902901
# 998                0.903361
# 999                0.903821
# 1000               0.904281
# 1001               0.904731
# 1002               0.905181
# 1003               0.905631
# 1004               0.906081
# 1005               0.906531
# 1006               0.906981
# 1007               0.907431
# 1008               0.907881
# 1009               0.908331
# 1010               0.908781
# 1011               0.909231
# 1012               0.909681
# 1013               0.910131
# 1014               0.910581
# 1015               0.911031
# 1016               0.911481
# 1017               0.911931
# 1018               0.912381
# 1019               0.912831
# 1020               0.913271
# 1021               0.913711
# 1022               0.914151
# 1023               0.914591
# 1024               0.915031
# 1025               0.915471
# 1026               0.915911
# 1027               0.916351
# 1028               0.916791
# 1029               0.917231
# 1030               0.917671
# 1031               0.918111
# 1032               0.918551
# 1033               0.918991
# 1034               0.919431
# 1035               0.919871
# 1036               0.920311
# 1037               0.920751
# 1038               0.921191
# 1039               0.921631
# 1040               0.922061
# 1041               0.922491
# 1042               0.922921
# 1043               0.923351
# 1044               0.923781
# 1045               0.924211
# 1046               0.924641
# 1047               0.925071
# 1048               0.925501
# 1049               0.925931
# 1050               0.926361
# 1051               0.926791
# 1052               0.927211
# 1053               0.927631
# 1054               0.928051
# 1055               0.928471
# 1056               0.928891
# 1057               0.929311
# 1058               0.929731
# 1059               0.930151
# 1060               0.930571
# 1061               0.930991
# 1062               0.931411
# 1063               0.931831
# 1064               0.932250
# 1065               0.932670
# 1066               0.933090
# 1067               0.933510
# 1068               0.933930
# 1069               0.934350
# 1070               0.934770
# 1071               0.935180
# 1072               0.935590
# 1073               0.936000
# 1074               0.936410
# 1075               0.936820
# 1076               0.937230
# 1077               0.937640
# 1078               0.938051
# 1079               0.938461
# 1080               0.938871
# 1081               0.939281
# 1082               0.939691
# 1083               0.940101
# 1084               0.940511
# 1085               0.940921
# 1086               0.941331
# 1087               0.941741
# 1088               0.942151
# 1089               0.942551
# 1090               0.942951
# 1091               0.943351
# 1092               0.943751
# 1093               0.944151
# 1094               0.944551
# 1095               0.944951
# 1096               0.945351
# 1097               0.945751
# 1098               0.946151
# 1099               0.946551
# 1100               0.946951
# 1101               0.947351
# 1102               0.947751
# 1103               0.948151
# 1104               0.948551
# 1105               0.948951
# 1106               0.949351
# 1107               0.949751
# 1108               0.950141
# 1109               0.950531
# 1110               0.950921
# 1111               0.951311
# 1112               0.951701
# 1113               0.952091
# 1114               0.952481
# 1115               0.952871
# 1116               0.953261
# 1117               0.953651
# 1118               0.954031
# 1119               0.954411
# 1120               0.954791
# 1121               0.955171
# 1122               0.955551
# 1123               0.955931
# 1124               0.956311
# 1125               0.956691
# 1126               0.957071
# 1127               0.957451
# 1128               0.957831
# 1129               0.958201
# 1130               0.958571
# 1131               0.958941
# 1132               0.959311
# 1133               0.959681
# 1134               0.960051
# 1135               0.960421
# 1136               0.960791
# 1137               0.961161
# 1138               0.961531
# 1139               0.961901
# 1140               0.962261
# 1141               0.962621
# 1142               0.962981
# 1143               0.963341
# 1144               0.963701
# 1145               0.964061
# 1146               0.964421
# 1147               0.964781
# 1148               0.965141
# 1149               0.965501
# 1150               0.965861
# 1151               0.966221
# 1152               0.966581
# 1153               0.966931
# 1154               0.967281
# 1155               0.967631
# 1156               0.967981
# 1157               0.968331
# 1158               0.968681
# 1159               0.969031
# 1160               0.969381
# 1161               0.969731
# 1162               0.970081
# 1163               0.970431
# 1164               0.970781
# 1165               0.971131
# 1166               0.971471
# 1167               0.971811
# 1168               0.972151
# 1169               0.972491
# 1170               0.972831
# 1171               0.973171
# 1172               0.973511
# 1173               0.973851
# 1174               0.974191
# 1175               0.974531
# 1176               0.974871
# 1177               0.975211
# 1178               0.975551
# 1179               0.975891
# 1180               0.976221
# 1181               0.976551
# 1182               0.976881
# 1183               0.977211
# 1184               0.977541
# 1185               0.977871
# 1186               0.978201
# 1187               0.978531
# 1188               0.978860
# 1189               0.979190
# 1190               0.979520
# 1191               0.979850
# 1192               0.980180
# 1193               0.980500
# 1194               0.980820
# 1195               0.981140
# 1196               0.981460
# 1197               0.981780
# 1198               0.982100
# 1199               0.982421
# 1200               0.982741
# 1201               0.983061
# 1202               0.983381
# 1203               0.983701
# 1204               0.984011
# 1205               0.984321
# 1206               0.984631
# 1207               0.984941
# 1208               0.985251
# 1209               0.985561
# 1210               0.985861
# 1211               0.986161
# 1212               0.986461
# 1213               0.986761
# 1214               0.987051
# 1215               0.987341
# 1216               0.987630
# 1217               0.987911
# 1218               0.988191
# 1219               0.988471
# 1220               0.988751
# 1221               0.989031
# 1222               0.989301
# 1223               0.989571
# 1224               0.989841
# 1225               0.990111
# 1226               0.990371
# 1227               0.990631
# 1228               0.990891
# 1229               0.991151
# 1230               0.991401
# 1231               0.991651
# 1232               0.991891
# 1233               0.992131
# 1234               0.992371
# 1235               0.992611
# 1236               0.992851
# 1237               0.993081
# 1238               0.993311
# 1239               0.993541
# 1240               0.993771
# 1241               0.993991
# 1242               0.994211
# 1243               0.994431
# 1244               0.994651
# 1245               0.994871
# 1246               0.995081
# 1247               0.995291
# 1248               0.995501
# 1249               0.995701
# 1250               0.995901
# 1251               0.996101
# 1252               0.996301
# 1253               0.996501
# 1254               0.996701
# 1255               0.996901
# 1256               0.997091
# 1257               0.997281
# 1258               0.997471
# 1259               0.997651
# 1260               0.997831
# 1261               0.998011
# 1262               0.998181
# 1263               0.998351
# 1264               0.998521
# 1265               0.998691
# 1266               0.998851
# 1267               0.999001
# 1268               0.999151
# 1269               0.999291
# 1270               0.999421
# 1271               0.999551
# 1272               0.999671
# 1273               0.999791
# 1274               0.999901
# 1275               1.000011
# 1276               1.000091
# 1277               1.000171
# 1278               1.000201
# 1279               1.000201
# 1280               1.000201
# 1281               1.000201
# 1282               1.000201
# 1283               1.000201
# 1284               1.000201
# 1285               1.000201
# 1286               1.000201
# 1287               1.000201
# 1288               1.000201
# 1289               1.000201
# 1290               1.000201
# 1291               1.000201
# 1292               1.000201
# 1293               1.000201
# 1294               1.000201
# 1295               1.000201
# 1296               1.000201
# 1297               1.000201
# 1298               1.000201
# 1299               1.000201
# 1300               1.000201
# 1301               1.000201
# 1302               1.000201
# 1303               1.000201
# 1304               1.000201
# 1305               1.000201
# 1306               1.000201
# 1307               1.000201
# 1308               1.000201
# 1309               1.000201
# 1310               1.000201
# 1311               1.000201
# 1312               1.000201
# 1313               1.000201
# 1314               1.000201
# 1315               1.000201
# 1316               1.000201
# 1317               1.000201
# 1318               1.000201
# 1319               1.000201
# 1320               1.000201
# 1321               1.000201
# 1322               1.000201
# 1323               1.000201
# 1324               1.000201
# 1325               1.000201
# 1326               1.000201
# 1327               1.000201
# 1328               1.000201
# 1329               1.000201
# 1330               1.000201
# 1331               1.000201
# 1332               1.000201
# 1333               1.000201
# 1334               1.000201
# 1335               1.000201
# 1336               1.000201
# 1337               1.000201
# 1338               1.000201
# 1339               1.000201
# 1340               1.000201
# 1341               1.000201
# 1342               1.000201
# 1343               1.000201
# 1344               1.000201
# 1345               1.000201
# 1346               1.000201
# 1347               1.000201
# 1348               1.000201
# 1349               1.000201
# 1350               1.000201
# 1351               1.000201
# 1352               1.000201
# 1353               1.000201
# 1354               1.000201
# 1355               1.000201
# 1356               1.000201
# 1357               1.000201
# 1358               1.000201
# 1359               1.000201
# 1360               1.000201
# 1361               1.000201
# 1362               1.000201
# 1363               1.000201
# 1364               1.000201
# 1365               1.000201
# 1366               1.000201
# 1367               1.000201
# 1368               1.000201
# 1369               1.000201
# 1370               1.000201
# 1371               1.000201
# 1372               1.000201
# 1373               1.000201
# 1374               1.000201
# 1375               1.000201
# 1376               1.000201
# 1377               1.000201
# 1378               1.000201
# 1379               1.000201
# 1380               1.000201
# 1381               1.000201
# 1382               1.000201
# 1383               1.000201
# 1384               1.000201
# 1385               1.000201
# 1386               1.000201
# 1387               1.000201
# 1388               1.000201
# 1389               1.000201
# 1390               1.000201
# 1391               1.000201
# 1392               1.000201
# 1393               1.000201
# 1394               1.000201
# 1395               1.000201
# 1396               1.000201
# 1397               1.000201
# 1398               1.000201
# 1399               1.000201
# 1400               1.000201
# 1401               1.000201
# 1402               1.000201
# 1403               1.000201
# 1404               1.000201
# 1405               1.000201
# 1406               1.000201
# 1407               1.000201
# 1408               1.000201
# 1409               1.000201
# 1410               1.000201
# 1411               1.000201
# 1412               1.000201
# 1413               1.000201
# 1414               1.000201
# 1415               1.000201
# 1416               1.000201
# 1417               1.000201
# 1418               1.000201
# 1419               1.000201
# 1420               1.000201
# 1421               1.000201
# 1422               1.000201
# 1423               1.000201
# 1424               1.000201
# 1425               1.000201
# 1426               1.000201
# 1427               1.000201
# 1428               1.000201
# 1429               1.000201
# 1430               1.000201
# 1431               1.000201
# 1432               1.000201
# 1433               1.000201
# 1434               1.000201
# 1435               1.000201
# 1436               1.000201
# 1437               1.000201
# 1438               1.000201
# 1439               1.000201
# 1440               1.000201
# 1441               1.000201
# 1442               1.000201
# 1443               1.000201
# 1444               1.000201
# 1445               1.000201
# 1446               1.000201
# 1447               1.000201
# 1448               1.000201
# 1449               1.000201
# 1450               1.000201
# 1451               1.000201
# 1452               1.000201
# 1453               1.000201
# 1454               1.000201
# 1455               1.000201
# 1456               1.000201
# 1457               1.000201
# 1458               1.000201
# 1459               1.000201
# 1460               1.000201
# 1461               1.000201
# 1462               1.000201
# 1463               1.000201
# 1464               1.000201
# 1465               1.000201
# 1466               1.000201
# 1467               1.000201

# %%
# example
feature_importance_df.iloc[3, 1]
# Out:
# 'encoder__membership_category+complaint_status_No MembershipUnsolved'

# %%
pd.reset_option('display.max_rows')

# %%
# let's select the first 100 features where they have importance of around 30%
# important_features = feature_importance_df.iloc[:99]['index'].tolist()
# X_train_preprocessed_selected = X_train_preprocessed[:, important_features]
# ... let's continue this code in a separate notebook for model development!

# %% [markdown]
# ### Save preprocessed data (ready for modeling)

# %%
train_split_preprocessed = pd.concat([X_train_preprocessed, y_train], axis=1)
# use .parquet instead of .csv as the csv version is too large (> 100 MB), 
# so it cannot be uploaded to GitHub
train_split_preprocessed.to_parquet('train_split_preprocessed.parquet', index=False)

# %% [markdown]
# ### Save pipelines & models

# %%
import joblib
joblib.dump(featureEng_encoder_scaler_pipeline, 'featureEng_encoder_scaler_pipeline.joblib')
joblib.dump(xgb_clf, 'xgb_clf_all_features.joblib')
# Out:
# ['xgb_clf_all_features.joblib']
