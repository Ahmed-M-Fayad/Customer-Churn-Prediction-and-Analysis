# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from itertools import combinations
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load data

# %%
train_cleaned = pd.read_csv("https://raw.githubusercontent.com/Ahmed-M-Fayad/Customer-Churn-Prediction-and-Analysis/refs/heads/Data-Cleaning/Data%20Collection%2C%20Exploration%2C%20and%20Preprocessing/Delivered%20Data/train_cleaned_imputed.csv")
train_cleaned.head()
# Out:
#    age gender region_category  membership_category joining_date  \
# 0   18      F         Village  Platinum Membership   2017-08-17
# 1   32      F            City   Premium Membership   2017-08-28
# 2   44      F            Town        No Membership   2016-11-11
# 3   37      M            City        No Membership   2016-10-29
# 4   31      F            City        No Membership   2017-09-12
#
#   joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                      No     Gift Vouchers/Coupons             Desktop
# 1                      No     Gift Vouchers/Coupons             Desktop
# 2                     Yes     Gift Vouchers/Coupons             Desktop
# 3                     Yes     Gift Vouchers/Coupons             Desktop
# 4                      No  Credit/Debit Card Offers          Smartphone
#
#   internet_option last_visit_time  ...  avg_time_spent  avg_transaction_value  \
# 0           Wi-Fi        16:08:02  ...          300.63               53005.25
# 1     Mobile_Data        12:38:13  ...          306.34               12838.38
# 2           Wi-Fi        22:53:21  ...          516.16               21027.00
# 3     Mobile_Data        15:57:50  ...           53.27               25239.56
# 4     Mobile_Data        15:46:44  ...          113.13               24483.66
#
#    avg_frequency_login_days  points_in_wallet  used_special_discount  \
# 0                      17.0        781.750000                    Yes
# 1                      10.0        792.852122                    Yes
# 2                      22.0        500.690000                     No
# 3                       6.0        567.660000                     No
# 4                      16.0        663.060000                     No
#
#   offer_application_preference past_complaint     complaint_status  \
# 0                          Yes             No       Not Applicable
# 1                           No            Yes               Solved
# 2                          Yes            Yes  Solved in Follow-up
# 3                          Yes            Yes             Unsolved
# 4                          Yes            Yes               Solved
#
#                    feedback churn_risk_score
# 0  Products always in Stock              2.0
# 1     Quality Customer Care              1.0
# 2              Poor Website              5.0
# 3              Poor Website              5.0
# 4              Poor Website              5.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Create a copy for feature engineering

# %%
train_cleaned_copy = train_cleaned.copy()

# %% [markdown]
# ### Explore columns

# %%
train_cleaned_copy.columns
# Out:
# Index(['age', 'gender', 'region_category', 'membership_category',
#        'joining_date', 'joined_through_referral', 'preferred_offer_types',
#        'medium_of_operation', 'internet_option', 'last_visit_time',
#        'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
#        'avg_frequency_login_days', 'points_in_wallet', 'used_special_discount',
#        'offer_application_preference', 'past_complaint', 'complaint_status',
#        'feedback', 'churn_risk_score'],
#       dtype='object')

# %%
train_cleaned_copy.select_dtypes('number').columns
# Out:
# Index(['age', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'avg_frequency_login_days', 'points_in_wallet',
#        'churn_risk_score'],
#       dtype='object')

# %% [markdown]
# ### Extracting features

# %%
train_cleaned_copy['points_per_transaction'] = train_cleaned_copy['points_in_wallet'] / train_cleaned_copy['avg_transaction_value']
train_cleaned_copy['transaction_value_per_time_unit'] = train_cleaned_copy['avg_transaction_value'] / train_cleaned_copy['avg_time_spent']

# %%
def time_of_day(hour):
	if 5 <= hour < 12:
		return 'Morning'
	elif 12 <= hour < 17:
		return 'Afternoon'
	elif 17 <= hour < 21:
		return 'Evening'
	else:
		return 'Night'

# %%
def ampm_mapping(hour):
	if 0 <= hour < 12:
		return 'AM'
	else:
		return 'PM'

# %%
train_cleaned_copy['last_visit_hour'] = pd.to_datetime(train_cleaned_copy['last_visit_time']).dt.hour
train_cleaned_copy['last_visit_time_of_day'] = train_cleaned_copy['last_visit_hour'].apply(time_of_day)
train_cleaned_copy['last_visit_AMPM'] = train_cleaned_copy['last_visit_hour'].apply(ampm_mapping)

# %%
train_cleaned_copy['joining_date'] = pd.to_datetime(train_cleaned_copy['joining_date'])
train_cleaned_copy['joining_day_name'] = train_cleaned_copy['joining_date'].dt.day_name()

# %%
train_cleaned_copy['is_weekend'] = ((train_cleaned_copy['joining_day_name'] == 'Sunday') |
									(train_cleaned_copy['joining_day_name'] == 'Saturday')).astype(int)

# %% [markdown]
# ### Save data (ready for advanced analysis)

# %%
train_cleaned_copy.isna().sum()
# Out:
# age                                0
# gender                             0
# region_category                    0
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# preferred_offer_types              0
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                   0
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# points_per_transaction             0
# transaction_value_per_time_unit    0
# last_visit_hour                    0
# last_visit_time_of_day             0
# last_visit_AMPM                    0
# joining_day_name                   0
# is_weekend                         0
# dtype: int64

# %%
train_cleaned_copy.to_csv('train_basicFeatureEng.csv', index=False)

# %%
train_cleaned_copy.select_dtypes(np.number).columns.tolist()
# Out:
# ['age',
#  'days_since_last_login',
#  'avg_time_spent',
#  'avg_transaction_value',
#  'avg_frequency_login_days',
#  'points_in_wallet',
#  'churn_risk_score',
#  'points_per_transaction',
#  'transaction_value_per_time_unit',
#  'last_visit_hour',
#  'is_weekend']

# %%
scale_cols = ['age', 'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
			  'avg_frequency_login_days', 'points_in_wallet', 'points_per_transaction',
              'transaction_value_per_time_unit', 'last_visit_hour']

# %% [markdown]
# ## Encoding categorical variables

# %%
for col in train_cleaned_copy.select_dtypes(exclude='number').columns:
	if col in ['joining_date', 'last_visit_time']:
		continue
	print(f'{col} Column', '-'*50)
	print(train_cleaned_copy[col].unique())
# Out:
# gender Column --------------------------------------------------
# ['F' 'M']
# region_category Column --------------------------------------------------
# ['Village' 'City' 'Town']
# membership_category Column --------------------------------------------------
# ['Platinum Membership' 'Premium Membership' 'No Membership'
#  'Gold Membership' 'Silver Membership' 'Basic Membership']
# joined_through_referral Column --------------------------------------------------
# ['No' 'Yes']
# preferred_offer_types Column --------------------------------------------------
# ['Gift Vouchers/Coupons' 'Credit/Debit Card Offers' 'Without Offers']
# medium_of_operation Column --------------------------------------------------
# ['Desktop' 'Smartphone' 'Both']
# internet_option Column --------------------------------------------------
# ['Wi-Fi' 'Mobile_Data' 'Fiber_Optic']
# used_special_discount Column --------------------------------------------------
# ['Yes' 'No']
# offer_application_preference Column --------------------------------------------------
# ['Yes' 'No']
# past_complaint Column --------------------------------------------------
# ['No' 'Yes']
# complaint_status Column --------------------------------------------------
# ['Not Applicable' 'Solved' 'Solved in Follow-up' 'Unsolved'
#  'No Information Available']
# feedback Column --------------------------------------------------
# ['Products always in Stock' 'Quality Customer Care' 'Poor Website'
#  'Too many ads' 'Poor Product Quality' 'Poor Customer Service'
#  'User Friendly Website' 'Reasonable Price']
# last_visit_time_of_day Column --------------------------------------------------
# ['Afternoon' 'Night' 'Morning' 'Evening']
# last_visit_AMPM Column --------------------------------------------------
# ['PM' 'AM']
# joining_day_name Column --------------------------------------------------
# ['Thursday' 'Monday' 'Friday' 'Saturday' 'Tuesday' 'Wednesday' 'Sunday']

# %%
one_hot_cols = list(set(train_cleaned_copy.select_dtypes(exclude='number').columns.tolist()) -
					{'joining_date', 'last_visit_time'} - {'membership_category', 'feedback'})
one_hot_cols
# Out:
# ['last_visit_AMPM',
#  'last_visit_time_of_day',
#  'preferred_offer_types',
#  'joining_day_name',
#  'offer_application_preference',
#  'used_special_discount',
#  'past_complaint',
#  'complaint_status',
#  'internet_option',
#  'joined_through_referral',
#  'region_category',
#  'medium_of_operation',
#  'gender']

# %% [markdown]
# #### One-Hot Encoding (includes binary encoding)

# %%
train_cleaned_copy = pd.get_dummies(train_cleaned_copy, columns=one_hot_cols, drop_first=True, dtype=int)

# %% [markdown]
# #### Ordinal Encoding

# %%
# ordinal_cols = ['membership_category', 'feedback']
train_cleaned_copy['membership_category'] = pd.Categorical(train_cleaned_copy['membership_category'],
														   categories=['No Membership', 'Basic Membership', 'Silver Membership',
																	   'Gold Membership', 'Platinum Membership', 'Premium Membership'],
															ordered=True).codes

# %%
positive_feedback = ['Products always in Stock', 'Quality Customer Care', 'Reasonable Price', 'User Friendly Website']
negative_feedback = ['Poor Website' ,'Poor Customer Service', 'Poor Product Quality', 'Too many ads']
neutral_feedback = ['No reason specified']

def get_sentiment(feedback):
	if feedback in positive_feedback:
		return 1
	elif feedback in negative_feedback:
		return -1
	else:
		return 0 # neutral

train_cleaned_copy['feedback'] = train_cleaned_copy['feedback'].transform(get_sentiment)

# %% [markdown]
# #### General transformations numeric features

# %%
for num_col in train_cleaned_copy.select_dtypes(include=np.number).columns:
	train_cleaned_copy[f'{num_col}_sqrt'] = np.sqrt(train_cleaned_copy[num_col] + 1)
	train_cleaned_copy[f'{num_col}_square'] = np.square(train_cleaned_copy[num_col])
	train_cleaned_copy[f'{num_col}_log'] = np.log1p(train_cleaned_copy[num_col] + 0.01)

# %% [markdown]
# The cell below is from the EDA.ipynb notebook in milestone 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# log1p(x) = log(x + 1): this avoids errors when x = 0
train_cleaned_copy['log_avg_time_spent'] = np.log1p(train_cleaned_copy['avg_time_spent'])

fig, axes = plt.subplots(1, 2)
sns.violinplot(train_cleaned_copy['avg_time_spent'], ax=axes[0])
sns.violinplot(train_cleaned_copy['log_avg_time_spent'], ax=axes[1])
plt.tight_layout()
plt.show()

# %%
train_cleaned_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35829 entries, 0 to 35828
# Columns: 163 entries, age to log_avg_time_spent
# dtypes: datetime64[ns](1), float16(1), float64(96), int32(2), int64(60), int8(2), object(1)
# memory usage: 43.6+ MB

# %%
pd.set_option('display.max_rows', None)
train_cleaned_copy.corr(numeric_only=True)['churn_risk_score'].sort_values(ascending=False)
# Out:
# churn_risk_score                                      1.000000
# churn_risk_score_sqrt                                 0.996109
# churn_risk_score_log                                  0.983755
# churn_risk_score_square                               0.979841
# avg_frequency_login_days_log                          0.276144
# avg_frequency_login_days_sqrt                         0.259230
# avg_frequency_login_days                              0.238092
# avg_frequency_login_days_square                       0.183887
# joined_through_referral_Yes_sqrt                      0.070965
# joined_through_referral_Yes_log                       0.070965
# joined_through_referral_Yes_square                    0.070965
# joined_through_referral_Yes                           0.070965
# preferred_offer_types_Without Offers_log              0.062684
# preferred_offer_types_Without Offers_square           0.062684
# preferred_offer_types_Without Offers                  0.062684
# preferred_offer_types_Without Offers_sqrt             0.062684
# medium_of_operation_Smartphone_square                 0.048564
# medium_of_operation_Smartphone                        0.048564
# medium_of_operation_Smartphone_sqrt                   0.048564
# medium_of_operation_Smartphone_log                    0.048564
# points_per_transaction_log                            0.042879
# points_per_transaction_sqrt                           0.040117
# points_per_transaction                                0.037179
# days_since_last_login_log                             0.031116
# days_since_last_login_sqrt                            0.030501
# days_since_last_login                                 0.029158
# days_since_last_login_square                          0.025458
# region_category_Town                                  0.012645
# region_category_Town_square                           0.012645
# region_category_Town_log                              0.012645
# region_category_Town_sqrt                             0.012645
# past_complaint_Yes_sqrt                               0.012207
# past_complaint_Yes                                    0.012207
# past_complaint_Yes_square                             0.012207
# past_complaint_Yes_log                                0.012207
# points_per_transaction_square                         0.009452
# last_visit_time_of_day_Morning_log                    0.009076
# last_visit_time_of_day_Morning                        0.009076
# last_visit_time_of_day_Morning_square                 0.009076
# last_visit_time_of_day_Morning_sqrt                   0.009076
# complaint_status_Solved in Follow-up                  0.008884
# complaint_status_Solved in Follow-up_square           0.008884
# complaint_status_Solved in Follow-up_log              0.008884
# complaint_status_Solved in Follow-up_sqrt             0.008884
# complaint_status_Solved_square                        0.007241
# complaint_status_Solved                               0.007241
# complaint_status_Solved_log                           0.007241
# complaint_status_Solved_sqrt                          0.007241
# joining_day_name_Tuesday_log                          0.005528
# joining_day_name_Tuesday_square                       0.005528
# joining_day_name_Tuesday                              0.005528
# joining_day_name_Tuesday_sqrt                         0.005528
# joining_day_name_Monday_sqrt                          0.004507
# joining_day_name_Monday                               0.004507
# joining_day_name_Monday_square                        0.004507
# joining_day_name_Monday_log                           0.004507
# joining_day_name_Thursday_log                         0.004140
# joining_day_name_Thursday                             0.004140
# joining_day_name_Thursday_square                      0.004140
# joining_day_name_Thursday_sqrt                        0.004140
# age_log                                               0.002782
# age_sqrt                                              0.002615
# age                                                   0.002400
# joining_day_name_Saturday                             0.002120
# joining_day_name_Saturday_square                      0.002120
# joining_day_name_Saturday_log                         0.002120
# joining_day_name_Saturday_sqrt                        0.002120
# age_square                                            0.001991
# last_visit_time_of_day_Evening_sqrt                   0.001785
# last_visit_time_of_day_Evening                        0.001785
# last_visit_time_of_day_Evening_square                 0.001785
# last_visit_time_of_day_Evening_log                    0.001785
# internet_option_Mobile_Data_log                       0.001271
# internet_option_Mobile_Data_square                    0.001271
# internet_option_Mobile_Data                           0.001271
# internet_option_Mobile_Data_sqrt                      0.001271
# complaint_status_Unsolved_sqrt                       -0.001923
# complaint_status_Unsolved                            -0.001923
# complaint_status_Unsolved_square                     -0.001923
# complaint_status_Unsolved_log                        -0.001923
# internet_option_Wi-Fi_log                            -0.002215
# internet_option_Wi-Fi_square                         -0.002215
# internet_option_Wi-Fi                                -0.002215
# internet_option_Wi-Fi_sqrt                           -0.002215
# is_weekend_log                                       -0.003453
# is_weekend_sqrt                                      -0.003453
# is_weekend_square                                    -0.003453
# is_weekend                                           -0.003453
# gender_M_sqrt                                        -0.003978
# gender_M_log                                         -0.003978
# gender_M                                             -0.003978
# gender_M_square                                      -0.003978
# last_visit_time_of_day_Night_sqrt                    -0.004540
# last_visit_time_of_day_Night_log                     -0.004540
# last_visit_time_of_day_Night                         -0.004540
# last_visit_time_of_day_Night_square                  -0.004540
# joining_day_name_Wednesday_sqrt                      -0.006490
# joining_day_name_Wednesday                           -0.006490
# joining_day_name_Wednesday_square                    -0.006490
# joining_day_name_Wednesday_log                       -0.006490
# joining_day_name_Sunday_sqrt                         -0.006548
# joining_day_name_Sunday                              -0.006548
# joining_day_name_Sunday_square                       -0.006548
# joining_day_name_Sunday_log                          -0.006548
# last_visit_hour_log                                  -0.007059
# last_visit_hour_sqrt                                 -0.007428
# last_visit_hour_square                               -0.007578
# last_visit_hour                                      -0.007625
# last_visit_AMPM_PM_sqrt                              -0.008031
# last_visit_AMPM_PM_log                               -0.008031
# last_visit_AMPM_PM                                   -0.008031
# last_visit_AMPM_PM_square                            -0.008031
# used_special_discount_Yes_sqrt                       -0.010971
# used_special_discount_Yes_log                        -0.010971
# used_special_discount_Yes_square                     -0.010971
# used_special_discount_Yes                            -0.010971
# complaint_status_Not Applicable_log                  -0.012207
# complaint_status_Not Applicable_sqrt                 -0.012207
# complaint_status_Not Applicable                      -0.012207
# complaint_status_Not Applicable_square               -0.012207
# avg_time_spent_square                                -0.017077
# avg_time_spent                                       -0.027442
# avg_time_spent_sqrt                                  -0.032835
# medium_of_operation_Desktop_sqrt                     -0.034753
# medium_of_operation_Desktop_log                      -0.034753
# medium_of_operation_Desktop_square                   -0.034753
# medium_of_operation_Desktop                          -0.034753
# log_avg_time_spent                                   -0.035081
# avg_time_spent_log                                   -0.035081
# offer_application_preference_Yes_log                 -0.035571
# offer_application_preference_Yes                     -0.035571
# offer_application_preference_Yes_square              -0.035571
# offer_application_preference_Yes_sqrt                -0.035571
# region_category_Village                              -0.037567
# region_category_Village_square                       -0.037567
# region_category_Village_sqrt                         -0.037567
# region_category_Village_log                          -0.037567
# transaction_value_per_time_unit_square               -0.055716
# preferred_offer_types_Gift Vouchers/Coupons_log      -0.059039
# preferred_offer_types_Gift Vouchers/Coupons_square   -0.059039
# preferred_offer_types_Gift Vouchers/Coupons          -0.059039
# preferred_offer_types_Gift Vouchers/Coupons_sqrt     -0.059039
# transaction_value_per_time_unit_log                  -0.115171
# transaction_value_per_time_unit_sqrt                 -0.130417
# transaction_value_per_time_unit                      -0.137613
# avg_transaction_value_log                            -0.218185
# points_in_wallet_log                                 -0.288484
# avg_transaction_value_sqrt                           -0.297490
# points_in_wallet_square                              -0.316108
# points_in_wallet_sqrt                                -0.329870
# points_in_wallet                                     -0.343697
# avg_transaction_value                                -0.363009
# avg_transaction_value_square                         -0.430248
# membership_category_square                           -0.697186
# membership_category_log                              -0.737604
# feedback_log                                         -0.748908
# feedback_sqrt                                        -0.748908
# feedback                                             -0.748908
# membership_category_sqrt                             -0.755268
# membership_category                                  -0.756212
# feedback_square                                            NaN
# Name: churn_risk_score, dtype: float64

# %%
train_cleaned_copy.isna().sum()[train_cleaned_copy.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# features that we may need to transform are:
#
# - `avg_time_spent`:
#
# 	avg_time_spent                                       -0.027045
#
# 	avg_time_spent_sqrt                                  -0.031828
#
# 	avg_time_spent_log                                   -0.032828
#
# - `avg_transaction_value`:
#
# 	avg_transaction_value                                -0.362539
#
# 	avg_transaction_value_square                         -0.429874

# %%
scale_cols.append('avg_transaction_value_square')

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# ## Build Feature Engineering pipeline

# %% [markdown]
# ### FeatureEng custom transformer

# %%
# X is DataFrame of training features
# r_list is a list of desired combination sizes
# returns DataFrame with new combination features, excluding original categorical columns
def create_categorical_combinations(X, r_list, cat_cols):
	df_str = X[cat_cols].astype(str) # to allow concatenation
	for r in r_list:
		# generate all combinations of length r
		combinations_iter = combinations(cat_cols, r)
		for comb in combinations_iter:
			df_str['+'.join(comb)] = df_str[list(comb)].agg(''.join, axis=1)
	return df_str.drop(columns=cat_cols)

# %%
class FeatureEng(BaseEstimator, TransformerMixin):
	def __init__(self):
		self.membership_order = ['No Membership', 'Basic Membership', 'Silver Membership',
								 'Gold Membership', 'Platinum Membership', 'Premium Membership']
		self.positive_feedback = ['Products always in Stock', 'Quality Customer Care', 'Reasonable Price', 'User Friendly Website']
		self.negative_feedback = ['Poor Website', 'Poor Customer Service', 'Poor Product Quality', 'Too many ads']

	def time_of_day(self, hour):
		if 5 <= hour < 12:
			return 'Morning'
		elif 12 <= hour < 17:
			return 'Afternoon'
		elif 17 <= hour < 21:
			return 'Evening'
		else:
			return 'Night'

	def ampm_mapping(self, hour):
		return 'AM' if 0 <= hour < 12 else 'PM'

	def get_sentiment(self, feedback):
		if feedback in self.positive_feedback:
			return 1
		elif feedback in self.negative_feedback:
			return -1
		else:
			return 0

	def fit(self, X, y=None):
		return self

	def transform(self, X):
		X = X.copy()

		X['points_per_transaction'] = X['points_in_wallet'] / X['avg_transaction_value']
		X['transaction_value_per_time_unit'] = X['avg_transaction_value'] / X['avg_time_spent']

		X['last_visit_hour'] = pd.to_datetime(X['last_visit_time']).dt.hour
		X['last_visit_time_of_day'] = X['last_visit_hour'].apply(self.time_of_day)
		X['last_visit_AMPM'] = X['last_visit_hour'].apply(self.ampm_mapping)
		X.drop('last_visit_time', axis=1, inplace=True)

		X['joining_date'] = pd.to_datetime(X['joining_date'])
		X['joining_day_name'] = X['joining_date'].dt.day_name()
		X['is_weekend'] = X['joining_day_name'].isin(['Saturday', 'Sunday']).astype(int)
		X.drop('joining_date', axis=1, inplace=True)

		cat_cols = list(X.select_dtypes(include=['object', 'category']).columns)
		cat_combos_df = create_categorical_combinations(X, range(2, 3), cat_cols)
		X = pd.concat([X, cat_combos_df], axis=1)

		X['membership_category'] = pd.Categorical( X['membership_category'],
												  categories=self.membership_order,
												  ordered=True).codes

		X['feedback'] = X['feedback'].apply(self.get_sentiment)

		X['avg_time_spent_log'] = np.log1p(X['avg_time_spent'])
		X['avg_transaction_value_square'] = np.square(X['avg_transaction_value'])

		return X

	def fit_transform(self, X, y=None):
		X_transformed = self.transform(X)
		self.feature_names_out_ = X_transformed.columns
		return X_transformed

	def get_feature_names_out(self, input_features=None):
		return self.feature_names_out_

# %% [markdown]
# ### encoder_scaler transformer

# %%
encoder_scaler_transformer = ColumnTransformer([
	('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype=int),
  make_column_selector(dtype_include=['object'])),
	('scaler', StandardScaler(), scale_cols)
], remainder='passthrough')

# %%
featureEng_encoder_scaler_pipeline = Pipeline([
    ('featureEng', FeatureEng()),
    ('encoder_scaler', encoder_scaler_transformer)
])

# %%
train_split_cleaned_imputed = pd.read_csv("https://raw.githubusercontent.com/Ahmed-M-Fayad/Customer-Churn-Prediction-and-Analysis/refs/heads/Data-Cleaning/Data%20Collection%2C%20Exploration%2C%20and%20Preprocessing/Delivered%20Data/train_split_cleaned_imputed.csv")

# %%
X_train = train_split_cleaned_imputed.drop(columns=['churn_risk_score'])
y_train = train_split_cleaned_imputed['churn_risk_score']

# %%
X_train_preprocessed = featureEng_encoder_scaler_pipeline.fit_transform(X_train)

# %%
len(featureEng_encoder_scaler_pipeline.get_feature_names_out())
# Out:
# 1583

# %%
train_cleaned_copy.shape[1]
# Out:
# 163

# %%
np.isinf(X_train_preprocessed).sum()
# Out:
# np.int64(0)

# %%
X_train_preprocessed = pd.DataFrame(X_train_preprocessed,
                                    columns=featureEng_encoder_scaler_pipeline.get_feature_names_out())

# %% [markdown]
# #### Feature selection & Importance

# %%
y_train.unique()
# Out:
# array([5., 3., 1., 2., 4.])

# %%
# target labels (y_train) starts from '1': [1, 2, 3, 4, 5],
# but XGBoost expects them to start from 0, like [0, 1, 2, 3, 4].
xgb_clf = XGBClassifier(random_state=42).fit(X_train_preprocessed, y_train-1)
# don't forget to add one in the prediction time:
# y_pred = xgb_clf.predict(X_test_preprocessed) + 1

# %%
pd.set_option('display.max_rows', None)
importances = xgb_clf.feature_importances_
feature_names = X_train_preprocessed.columns
feature_importance_df = pd.DataFrame({'feature':feature_names, 'importance':importances})
feature_importance_df['importance'] = feature_importance_df['importance'].round(5)
feature_importance_df = feature_importance_df.sort_values('importance', ascending=False).reset_index()
feature_importance_df['cumulative_importance'] = feature_importance_df['importance'].cumsum()
feature_importance_df
# Out:
#       index                                            feature  importance  \
# 0      1579                     remainder__membership_category     0.07034
# 1      1580                                remainder__feedback     0.05545
# 2         3                                encoder__gender_nan     0.02795
# 3      1574                           scaler__points_in_wallet     0.01664
# 4       456  encoder__membership_category+used_special_disc...     0.00182
# 5       160    encoder__gender+feedback_FQuality Customer Care     0.00176
# 6       625  encoder__membership_category+joining_day_name_...     0.00173
# 7       418  encoder__membership_category+medium_of_operati...     0.00163
# 8       800  encoder__preferred_offer_types+complaint_statu...     0.00163
# 9      1120  encoder__used_special_discount+feedback_NoNo r...     0.00161
# 10     1386  encoder__complaint_status+joining_day_name_Sol...     0.00151
# 11     1562  encoder__last_visit_AMPM+joining_day_name_PMMo...     0.00151
# 12       44                   encoder__joining_day_name_Friday     0.00149
# 13     1166  encoder__used_special_discount+joining_day_nam...     0.00147
# 14     1340  encoder__complaint_status+last_visit_time_of_d...     0.00146
# 15     1560  encoder__last_visit_AMPM+joining_day_name_AMWe...     0.00144
# 16      365  encoder__region_category+joining_day_name_City...     0.00144
# 17      457  encoder__membership_category+used_special_disc...     0.00141
# 18      474  encoder__membership_category+offer_application...     0.00141
# 19     1047  encoder__internet_option+feedback_Mobile_DataU...     0.00140
# 20     1241    encoder__past_complaint+feedback_NoPoor Website     0.00140
# 21       72  encoder__gender+membership_category_MPremium M...     0.00140
# 22       64  encoder__gender+membership_category_FNo Member...     0.00140
# 23     1304  encoder__complaint_status+feedback_Solved in F...     0.00139
# 24     1431  encoder__feedback+last_visit_time_of_day_Too m...     0.00132
# 25     1214  encoder__offer_application_preference+last_vis...     0.00131
# 26     1573                   scaler__avg_frequency_login_days     0.00130
# 27     1442  encoder__feedback+last_visit_AMPM_Poor Product...     0.00129
# 28     1555  encoder__last_visit_AMPM+joining_day_name_AMMo...     0.00129
# 29      466  encoder__membership_category+used_special_disc...     0.00129
# 30      966  encoder__medium_of_operation+last_visit_AMPM_D...     0.00126
# 31     1362  encoder__complaint_status+last_visit_AMPM_Unso...     0.00125
# 32     1322  encoder__complaint_status+feedback_UnsolvedNo ...     0.00122
# 33     1129  encoder__used_special_discount+feedback_YesNo ...     0.00121
# 34      461  encoder__membership_category+used_special_disc...     0.00121
# 35      989  encoder__medium_of_operation+joining_day_name_...     0.00120
# 36     1239  encoder__past_complaint+feedback_NoPoor Custom...     0.00120
# 37     1176  encoder__offer_application_preference+complain...     0.00120
# 38     1182  encoder__offer_application_preference+complain...     0.00119
# 39      813  encoder__preferred_offer_types+feedback_Credit...     0.00119
# 40      399  encoder__membership_category+preferred_offer_t...     0.00119
# 41     1567  encoder__last_visit_AMPM+joining_day_name_PMWe...     0.00118
# 42     1250   encoder__past_complaint+feedback_YesPoor Website     0.00118
# 43      868  encoder__preferred_offer_types+joining_day_nam...     0.00117
# 44      335  encoder__region_category+feedback_VillagePoor ...     0.00117
# 45      336  encoder__region_category+feedback_VillagePoor ...     0.00117
# 46      206          encoder__gender+joining_day_name_FTuesday     0.00117
# 47     1218  encoder__offer_application_preference+joining_...     0.00116
# 48     1294  encoder__complaint_status+feedback_No Informat...     0.00115
# 49     1539  encoder__last_visit_time_of_day+joining_day_na...     0.00114
# 50     1510  encoder__feedback+joining_day_name_Too many ad...     0.00113
# 51      582  encoder__membership_category+last_visit_time_o...     0.00113
# 52      661  encoder__joined_through_referral+medium_of_ope...     0.00112
# 53     1059  encoder__internet_option+last_visit_time_of_da...     0.00112
# 54      710  encoder__joined_through_referral+feedback_YesN...     0.00111
# 55      357    encoder__region_category+last_visit_AMPM_CityAM     0.00111
# 56     1014  encoder__internet_option+complaint_status_Fibe...     0.00111
# 57     1346  encoder__complaint_status+last_visit_time_of_d...     0.00111
# 58      586  encoder__membership_category+last_visit_time_o...     0.00111
# 59      826  encoder__preferred_offer_types+feedback_Withou...     0.00111
# 60      912  encoder__medium_of_operation+complaint_status_...     0.00111
# 61      834  encoder__preferred_offer_types+last_visit_time...     0.00111
# 62     1122  encoder__used_special_discount+feedback_NoPoor...     0.00110
# 63     1279  encoder__past_complaint+joining_day_name_YesMo...     0.00110
# 64     1557  encoder__last_visit_AMPM+joining_day_name_AMSu...     0.00110
# 65     1018  encoder__internet_option+complaint_status_Fibe...     0.00110
# 66     1200  encoder__offer_application_preference+feedback...     0.00109
# 67      933  encoder__medium_of_operation+feedback_DesktopP...     0.00109
# 68      612  encoder__membership_category+joining_day_name_...     0.00108
# 69     1532  encoder__last_visit_time_of_day+joining_day_na...     0.00108
# 70      720  encoder__joined_through_referral+last_visit_ti...     0.00108
# 71      536  encoder__membership_category+feedback_Gold Mem...     0.00108
# 72      806  encoder__preferred_offer_types+feedback_Credit...     0.00108
# 73      982  encoder__medium_of_operation+joining_day_name_...     0.00107
# 74     1264  encoder__past_complaint+last_visit_time_of_day...     0.00107
# 75      736  encoder__joined_through_referral+joining_day_n...     0.00107
# 76      211           encoder__gender+joining_day_name_MSunday     0.00107
# 77      714  encoder__joined_through_referral+feedback_YesP...     0.00107
# 78      845  encoder__preferred_offer_types+last_visit_time...     0.00107
# 79      695  encoder__joined_through_referral+complaint_sta...     0.00106
# 80     1405  encoder__feedback+last_visit_time_of_day_Poor ...     0.00106
# 81      596  encoder__membership_category+last_visit_time_o...     0.00106
# 82     1021  encoder__internet_option+complaint_status_Mobi...     0.00106
# 83      980  encoder__medium_of_operation+joining_day_name_...     0.00106
# 84      987  encoder__medium_of_operation+joining_day_name_...     0.00106
# 85     1287  encoder__complaint_status+feedback_No Informat...     0.00106
# 86      304  encoder__region_category+complaint_status_City...     0.00105
# 87      858  encoder__preferred_offer_types+joining_day_nam...     0.00105
# 88      144  encoder__gender+complaint_status_MNo Informati...     0.00105
# 89     1490  encoder__feedback+joining_day_name_Products al...     0.00105
# 90     1528  encoder__last_visit_time_of_day+joining_day_na...     0.00105
# 91      692  encoder__joined_through_referral+complaint_sta...     0.00104
# 92      911  encoder__medium_of_operation+complaint_status_...     0.00104
# 93     1506  encoder__feedback+joining_day_name_Too many ad...     0.00104
# 94      608  encoder__membership_category+last_visit_AMPM_S...     0.00104
# 95      622  encoder__membership_category+joining_day_name_...     0.00103
# 96     1186  encoder__offer_application_preference+feedback...     0.00103
# 97     1473  encoder__feedback+joining_day_name_Poor Produc...     0.00103
# 98      235  encoder__region_category+membership_category_V...     0.00103
# 99     1467  encoder__feedback+joining_day_name_Poor Custom...     0.00102
# 100    1335  encoder__complaint_status+last_visit_time_of_d...     0.00102
# 101    1090  encoder__internet_option+joining_day_name_Mobi...     0.00102
# 102    1523  encoder__last_visit_time_of_day+last_visit_AMP...     0.00102
# 103    1534  encoder__last_visit_time_of_day+joining_day_na...     0.00102
# 104     364  encoder__region_category+joining_day_name_City...     0.00101
# 105    1559  encoder__last_visit_AMPM+joining_day_name_AMTu...     0.00101
# 106     452  encoder__membership_category+internet_option_S...     0.00101
# 107     530  encoder__membership_category+feedback_Basic Me...     0.00101
# 108     839  encoder__preferred_offer_types+last_visit_time...     0.00101
# 109     574  encoder__membership_category+last_visit_time_o...     0.00101
# 110    1089  encoder__internet_option+joining_day_name_Mobi...     0.00101
# 111     386  encoder__membership_category+joined_through_re...     0.00100
# 112     629  encoder__membership_category+joining_day_name_...     0.00100
# 113     209           encoder__gender+joining_day_name_MMonday     0.00100
# 114    1262  encoder__past_complaint+last_visit_time_of_day...     0.00100
# 115    1472  encoder__feedback+joining_day_name_Poor Produc...     0.00100
# 116     965  encoder__medium_of_operation+last_visit_AMPM_B...     0.00100
# 117     628  encoder__membership_category+joining_day_name_...     0.00099
# 118    1440  encoder__feedback+last_visit_AMPM_Poor Custome...     0.00099
# 119    1084  encoder__internet_option+joining_day_name_Fibe...     0.00099
# 120     931  encoder__medium_of_operation+feedback_BothUser...     0.00099
# 121     373  encoder__region_category+joining_day_name_Town...     0.00099
# 122     749  encoder__preferred_offer_types+medium_of_opera...     0.00098
# 123    1393  encoder__complaint_status+joining_day_name_Uns...     0.00098
# 124    1145  encoder__used_special_discount+last_visit_time...     0.00098
# 125     816  encoder__preferred_offer_types+feedback_Gift V...     0.00098
# 126     595  encoder__membership_category+last_visit_time_o...     0.00097
# 127     509  encoder__membership_category+complaint_status_...     0.00097
# 128     738  encoder__joined_through_referral+joining_day_n...     0.00097
# 129     323  encoder__region_category+feedback_CityToo many...     0.00097
# 130     505  encoder__membership_category+complaint_status_...     0.00096
# 131     923  encoder__medium_of_operation+feedback_BothNo r...     0.00096
# 132     862  encoder__preferred_offer_types+joining_day_nam...     0.00096
# 133    1505  encoder__feedback+joining_day_name_Too many ad...     0.00096
# 134    1031  encoder__internet_option+feedback_Fiber_OpticP...     0.00096
# 135     203         encoder__gender+joining_day_name_FSaturday     0.00095
# 136     419  encoder__membership_category+medium_of_operati...     0.00095
# 137     133                encoder__gender+past_complaint_FYes     0.00095
# 138    1383  encoder__complaint_status+joining_day_name_Sol...     0.00095
# 139     495  encoder__membership_category+complaint_status_...     0.00094
# 140     766  encoder__preferred_offer_types+internet_option...     0.00094
# 141     223  encoder__region_category+membership_category_C...     0.00094
# 142     207        encoder__gender+joining_day_name_FWednesday     0.00094
# 143     493  encoder__membership_category+past_complaint_Si...     0.00094
# 144      62  encoder__gender+membership_category_FBasic Mem...     0.00094
# 145    1284  encoder__past_complaint+joining_day_name_YesWe...     0.00093
# 146     244  encoder__region_category+joined_through_referr...     0.00093
# 147    1249  encoder__past_complaint+feedback_YesPoor Produ...     0.00093
# 148     851  encoder__preferred_offer_types+last_visit_AMPM...     0.00093
# 149     538  encoder__membership_category+feedback_Gold Mem...     0.00093
# 150    1343  encoder__complaint_status+last_visit_time_of_d...     0.00093
# 151     905  encoder__medium_of_operation+past_complaint_Sm...     0.00093
# 152    1469  encoder__feedback+joining_day_name_Poor Custom...     0.00093
# 153     528  encoder__membership_category+feedback_Basic Me...     0.00093
# 154     410  encoder__membership_category+preferred_offer_t...     0.00093
# 155    1403  encoder__feedback+last_visit_time_of_day_No re...     0.00093
# 156     420  encoder__membership_category+medium_of_operati...     0.00093
# 157     939  encoder__medium_of_operation+feedback_DesktopT...     0.00093
# 158     914  encoder__medium_of_operation+complaint_status_...     0.00093
# 159      54           encoder__gender+region_category_FVillage     0.00092
# 160    1420  encoder__feedback+last_visit_time_of_day_Quali...     0.00092
# 161    1039  encoder__internet_option+feedback_Mobile_DataN...     0.00092
# 162     617  encoder__membership_category+joining_day_name_...     0.00092
# 163    1305  encoder__complaint_status+feedback_Solved in F...     0.00092
# 164     615  encoder__membership_category+joining_day_name_...     0.00092
# 165    1398  encoder__complaint_status+joining_day_name_Uns...     0.00092
# 166    1165  encoder__used_special_discount+joining_day_nam...     0.00092
# 167    1204  encoder__offer_application_preference+last_vis...     0.00092
# 168    1452   encoder__feedback+last_visit_AMPM_Too many adsPM     0.00092
# 169     722  encoder__joined_through_referral+last_visit_ti...     0.00092
# 170     753  encoder__preferred_offer_types+medium_of_opera...     0.00091
# 171    1465  encoder__feedback+joining_day_name_Poor Custom...     0.00091
# 172     349  encoder__region_category+last_visit_time_of_da...     0.00091
# 173    1076   encoder__internet_option+last_visit_AMPM_Wi-FiPM     0.00091
# 174    1543  encoder__last_visit_time_of_day+joining_day_na...     0.00091
# 175     743  encoder__joined_through_referral+joining_day_n...     0.00091
# 176     817  encoder__preferred_offer_types+feedback_Gift V...     0.00091
# 177    1530  encoder__last_visit_time_of_day+joining_day_na...     0.00091
# 178     810  encoder__preferred_offer_types+feedback_Credit...     0.00091
# 179     187    encoder__gender+last_visit_time_of_day_MMorning     0.00091
# 180     376  encoder__region_category+joining_day_name_Town...     0.00090
# 181      32  encoder__complaint_status_No Information Avail...     0.00090
# 182     916  encoder__medium_of_operation+complaint_status_...     0.00090
# 183    1180  encoder__offer_application_preference+complain...     0.00090
# 184     942  encoder__medium_of_operation+feedback_Smartpho...     0.00090
# 185     717  encoder__joined_through_referral+feedback_YesT...     0.00090
# 186     627  encoder__membership_category+joining_day_name_...     0.00090
# 187     935  encoder__medium_of_operation+feedback_DesktopP...     0.00090
# 188    1413  encoder__feedback+last_visit_time_of_day_Poor ...     0.00090
# 189    1046  encoder__internet_option+feedback_Mobile_DataT...     0.00089
# 190    1360  encoder__complaint_status+last_visit_AMPM_Solv...     0.00089
# 191     678  encoder__joined_through_referral+used_special_...     0.00089
# 192     594  encoder__membership_category+last_visit_time_o...     0.00089
# 193     915  encoder__medium_of_operation+complaint_status_...     0.00089
# 194     723  encoder__joined_through_referral+last_visit_ti...     0.00089
# 195     443  encoder__membership_category+internet_option_N...     0.00089
# 196    1415  encoder__feedback+last_visit_time_of_day_Poor ...     0.00089
# 197     469  encoder__membership_category+offer_application...     0.00088
# 198     698  encoder__joined_through_referral+complaint_sta...     0.00088
# 199    1192  encoder__offer_application_preference+feedback...     0.00088
# 200    1141  encoder__used_special_discount+last_visit_time...     0.00088
# 201     870  encoder__preferred_offer_types+joining_day_nam...     0.00088
# 202    1128  encoder__used_special_discount+feedback_NoUser...     0.00087
# 203     969  encoder__medium_of_operation+last_visit_AMPM_S...     0.00087
# 204     400  encoder__membership_category+preferred_offer_t...     0.00087
# 205    1286  encoder__complaint_status+feedback_No Informat...     0.00087
# 206     362  encoder__region_category+last_visit_AMPM_Villa...     0.00086
# 207     296    encoder__region_category+past_complaint_TownYes     0.00086
# 208    1011    encoder__internet_option+past_complaint_Wi-FiNo     0.00086
# 209     266  encoder__region_category+medium_of_operation_V...     0.00086
# 210    1359  encoder__complaint_status+last_visit_AMPM_Solv...     0.00086
# 211     901  encoder__medium_of_operation+past_complaint_Bo...     0.00086
# 212    1468  encoder__feedback+joining_day_name_Poor Custom...     0.00086
# 213     893  encoder__medium_of_operation+offer_application...     0.00086
# 214     788  encoder__preferred_offer_types+past_complaint_...     0.00086
# 215     746  encoder__joined_through_referral+joining_day_n...     0.00086
# 216     609  encoder__membership_category+last_visit_AMPM_S...     0.00086
# 217    1109  encoder__used_special_discount+complaint_statu...     0.00086
# 218     146           encoder__gender+complaint_status_MSolved     0.00086
# 219     182    encoder__gender+last_visit_time_of_day_FEvening     0.00085
# 220    1430  encoder__feedback+last_visit_time_of_day_Too m...     0.00085
# 221    1463  encoder__feedback+joining_day_name_Poor Custom...     0.00085
# 222    1238  encoder__past_complaint+feedback_NoNo reason s...     0.00085
# 223    1010  encoder__internet_option+past_complaint_Mobile...     0.00085
# 224    1213  encoder__offer_application_preference+last_vis...     0.00085
# 225     544  encoder__membership_category+feedback_No Membe...     0.00085
# 226     566  encoder__membership_category+feedback_Silver M...     0.00084
# 227     165    encoder__gender+feedback_MPoor Customer Service     0.00084
# 228    1118  encoder__used_special_discount+complaint_statu...     0.00084
# 229    1228  encoder__offer_application_preference+joining_...     0.00084
# 230     156    encoder__gender+feedback_FPoor Customer Service     0.00084
# 231    1263  encoder__past_complaint+last_visit_time_of_day...     0.00084
# 232    1435  encoder__feedback+last_visit_time_of_day_User ...     0.00084
# 233     428  encoder__membership_category+medium_of_operati...     0.00084
# 234     920  encoder__medium_of_operation+complaint_status_...     0.00084
# 235     932  encoder__medium_of_operation+feedback_DesktopN...     0.00084
# 236     326  encoder__region_category+feedback_TownPoor Cus...     0.00084
# 237    1074  encoder__internet_option+last_visit_AMPM_Mobil...     0.00084
# 238    1185  encoder__offer_application_preference+feedback...     0.00084
# 239     473  encoder__membership_category+offer_application...     0.00084
# 240    1400  encoder__feedback+last_visit_time_of_day_No re...     0.00084
# 241    1112  encoder__used_special_discount+complaint_statu...     0.00084
# 242    1538  encoder__last_visit_time_of_day+joining_day_na...     0.00084
# 243    1524  encoder__last_visit_time_of_day+last_visit_AMP...     0.00084
# 244     590  encoder__membership_category+last_visit_time_o...     0.00083
# 245    1476  encoder__feedback+joining_day_name_Poor Produc...     0.00083
# 246     575  encoder__membership_category+last_visit_time_o...     0.00083
# 247     687  encoder__joined_through_referral+past_complain...     0.00083
# 248     271  encoder__region_category+internet_option_CityW...     0.00083
# 249     958  encoder__medium_of_operation+last_visit_time_o...     0.00083
# 250     435  encoder__membership_category+medium_of_operati...     0.00083
# 251     381  encoder__region_category+joining_day_name_Vill...     0.00083
# 252     857  encoder__preferred_offer_types+joining_day_nam...     0.00083
# 253    1461  encoder__feedback+joining_day_name_No reason s...     0.00083
# 254     865  encoder__preferred_offer_types+joining_day_nam...     0.00083
# 255    1456  encoder__feedback+joining_day_name_No reason s...     0.00083
# 256      70  encoder__gender+membership_category_MNo Member...     0.00083
# 257    1221  encoder__offer_application_preference+joining_...     0.00083
# 258    1191  encoder__offer_application_preference+feedback...     0.00083
# 259     773  encoder__preferred_offer_types+used_special_di...     0.00083
# 260     157     encoder__gender+feedback_FPoor Product Quality     0.00082
# 261     651  encoder__membership_category+joining_day_name_...     0.00082
# 262    1414  encoder__feedback+last_visit_time_of_day_Poor ...     0.00082
# 263     318  encoder__region_category+feedback_CityPoor Pro...     0.00082
# 264     328  encoder__region_category+feedback_TownPoor Web...     0.00082
# 265    1151  encoder__used_special_discount+last_visit_AMPM...     0.00082
# 266     882  encoder__medium_of_operation+internet_option_S...     0.00082
# 267    1445  encoder__feedback+last_visit_AMPM_Products alw...     0.00082
# 268    1566  encoder__last_visit_AMPM+joining_day_name_PMTu...     0.00082
# 269    1565  encoder__last_visit_AMPM+joining_day_name_PMTh...     0.00082
# 270    1054  encoder__internet_option+feedback_Wi-FiReasona...     0.00082
# 271     234  encoder__region_category+membership_category_T...     0.00082
# 272     237  encoder__region_category+membership_category_V...     0.00082
# 273     317  encoder__region_category+feedback_CityPoor Cus...     0.00081
# 274     587  encoder__membership_category+last_visit_time_o...     0.00081
# 275     275  encoder__region_category+internet_option_Villa...     0.00081
# 276    1226  encoder__offer_application_preference+joining_...     0.00081
# 277     524  encoder__membership_category+complaint_status_...     0.00081
# 278     529  encoder__membership_category+feedback_Basic Me...     0.00081
# 279     659  encoder__joined_through_referral+preferred_off...     0.00081
# 280     747  encoder__joined_through_referral+joining_day_n...     0.00081
# 281    1281  encoder__past_complaint+joining_day_name_YesSu...     0.00080
# 282     598  encoder__membership_category+last_visit_AMPM_B...     0.00080
# 283      69  encoder__gender+membership_category_MGold Memb...     0.00080
# 284     655  encoder__joined_through_referral+preferred_off...     0.00080
# 285    1554  encoder__last_visit_AMPM+joining_day_name_AMFr...     0.00080
# 286     181  encoder__gender+last_visit_time_of_day_FAfternoon     0.00080
# 287     630  encoder__membership_category+joining_day_name_...     0.00080
# 288      84       encoder__gender+joined_through_referral_MYes     0.00080
# 289     739  encoder__joined_through_referral+joining_day_n...     0.00080
# 290     507  encoder__membership_category+complaint_status_...     0.00080
# 291     960  encoder__medium_of_operation+last_visit_time_o...     0.00080
# 292     298  encoder__region_category+past_complaint_Villag...     0.00080
# 293     352  encoder__region_category+last_visit_time_of_da...     0.00080
# 294     319  encoder__region_category+feedback_CityPoor Web...     0.00080
# 295     324  encoder__region_category+feedback_CityUser Fri...     0.00080
# 296     540  encoder__membership_category+feedback_No Membe...     0.00079
# 297     563  encoder__membership_category+feedback_Silver M...     0.00079
# 298    1045  encoder__internet_option+feedback_Mobile_DataR...     0.00079
# 299    1087  encoder__internet_option+joining_day_name_Mobi...     0.00079
# 300     368  encoder__region_category+joining_day_name_City...     0.00079
# 301     968  encoder__medium_of_operation+last_visit_AMPM_S...     0.00079
# 302     508  encoder__membership_category+complaint_status_...     0.00079
# 303     760  encoder__preferred_offer_types+internet_option...     0.00079
# 304     844  encoder__preferred_offer_types+last_visit_time...     0.00079
# 305     445  encoder__membership_category+internet_option_N...     0.00079
# 306    1364  encoder__complaint_status+joining_day_name_No ...     0.00079
# 307     484  encoder__membership_category+past_complaint_Go...     0.00079
# 308     439  encoder__membership_category+internet_option_B...     0.00079
# 309     951  encoder__medium_of_operation+last_visit_time_o...     0.00079
# 310    1117  encoder__used_special_discount+complaint_statu...     0.00079
# 311     943  encoder__medium_of_operation+feedback_Smartpho...     0.00079
# 312     919  encoder__medium_of_operation+complaint_status_...     0.00079
# 313    1058  encoder__internet_option+last_visit_time_of_da...     0.00079
# 314     998  encoder__internet_option+used_special_discount...     0.00079
# 315     170         encoder__gender+feedback_MReasonable Price     0.00078
# 316     676  encoder__joined_through_referral+used_special_...     0.00078
# 317    1545  encoder__last_visit_time_of_day+joining_day_na...     0.00078
# 318    1459  encoder__feedback+joining_day_name_No reason s...     0.00078
# 319     979  encoder__medium_of_operation+joining_day_name_...     0.00078
# 320     570  encoder__membership_category+feedback_Silver M...     0.00078
# 321    1402  encoder__feedback+last_visit_time_of_day_No re...     0.00078
# 322    1066  encoder__internet_option+last_visit_time_of_da...     0.00078
# 323    1437  encoder__feedback+last_visit_AMPM_No reason sp...     0.00078
# 324     828  encoder__preferred_offer_types+feedback_Withou...     0.00078
# 325    1069  encoder__internet_option+last_visit_time_of_da...     0.00078
# 326    1017  encoder__internet_option+complaint_status_Fibe...     0.00078
# 327     752  encoder__preferred_offer_types+medium_of_opera...     0.00078
# 328     741  encoder__joined_through_referral+joining_day_n...     0.00078
# 329     210         encoder__gender+joining_day_name_MSaturday     0.00078
# 330     486  encoder__membership_category+past_complaint_No...     0.00078
# 331    1411  encoder__feedback+last_visit_time_of_day_Poor ...     0.00078
# 332     576  encoder__membership_category+last_visit_time_o...     0.00078
# 333     894  encoder__medium_of_operation+offer_application...     0.00078
# 334     990  encoder__medium_of_operation+joining_day_name_...     0.00078
# 335     401  encoder__membership_category+preferred_offer_t...     0.00078
# 336    1544  encoder__last_visit_time_of_day+joining_day_na...     0.00077
# 337     327  encoder__region_category+feedback_TownPoor Pro...     0.00077
# 338    1181  encoder__offer_application_preference+complain...     0.00077
# 339    1037  encoder__internet_option+feedback_Fiber_OpticT...     0.00077
# 340     726  encoder__joined_through_referral+last_visit_ti...     0.00077
# 341    1240  encoder__past_complaint+feedback_NoPoor Produc...     0.00077
# 342     712  encoder__joined_through_referral+feedback_YesP...     0.00077
# 343     808  encoder__preferred_offer_types+feedback_Credit...     0.00077
# 344    1509  encoder__feedback+joining_day_name_Too many ad...     0.00077
# 345    1222  encoder__offer_application_preference+joining_...     0.00077
# 346     792  encoder__preferred_offer_types+complaint_statu...     0.00077
# 347     873  encoder__preferred_offer_types+joining_day_nam...     0.00077
# 348    1061  encoder__internet_option+last_visit_time_of_da...     0.00077
# 349     377  encoder__region_category+joining_day_name_Town...     0.00077
# 350     379  encoder__region_category+joining_day_name_Vill...     0.00077
# 351    1158  encoder__used_special_discount+joining_day_nam...     0.00077
# 352    1051  encoder__internet_option+feedback_Wi-FiPoor We...     0.00077
# 353    1114  encoder__used_special_discount+complaint_statu...     0.00077
# 354    1146  encoder__used_special_discount+last_visit_time...     0.00077
# 355     293     encoder__region_category+past_complaint_CityNo     0.00077
# 356    1088  encoder__internet_option+joining_day_name_Mobi...     0.00077
# 357     580  encoder__membership_category+last_visit_time_o...     0.00077
# 358     577  encoder__membership_category+last_visit_time_o...     0.00077
# 359     169    encoder__gender+feedback_MQuality Customer Care     0.00077
# 360      47                   encoder__joining_day_name_Sunday     0.00077
# 361    1561  encoder__last_visit_AMPM+joining_day_name_PMFr...     0.00077
# 362     624  encoder__membership_category+joining_day_name_...     0.00077
# 363     619  encoder__membership_category+joining_day_name_...     0.00076
# 364    1511  encoder__feedback+joining_day_name_Too many ad...     0.00076
# 365     991  encoder__medium_of_operation+joining_day_name_...     0.00076
# 366     877  encoder__medium_of_operation+internet_option_B...     0.00076
# 367     442  encoder__membership_category+internet_option_G...     0.00076
# 368    1003  encoder__internet_option+offer_application_pre...     0.00076
# 369    1139  encoder__used_special_discount+last_visit_time...     0.00076
# 370     744  encoder__joined_through_referral+joining_day_n...     0.00076
# 371    1063  encoder__internet_option+last_visit_time_of_da...     0.00076
# 372     205         encoder__gender+joining_day_name_FThursday     0.00076
# 373    1542  encoder__last_visit_time_of_day+joining_day_na...     0.00076
# 374    1381  encoder__complaint_status+joining_day_name_Sol...     0.00076
# 375     794  encoder__preferred_offer_types+complaint_statu...     0.00076
# 376    1350  encoder__complaint_status+last_visit_time_of_d...     0.00076
# 377    1220  encoder__offer_application_preference+joining_...     0.00076
# 378    1385  encoder__complaint_status+joining_day_name_Sol...     0.00076
# 379     196                encoder__gender+last_visit_AMPM_MAM     0.00075
# 380    1408  encoder__feedback+last_visit_time_of_day_Poor ...     0.00075
# 381    1407  encoder__feedback+last_visit_time_of_day_Poor ...     0.00075
# 382     921  encoder__medium_of_operation+complaint_status_...     0.00075
# 383    1242  encoder__past_complaint+feedback_NoProducts al...     0.00075
# 384     291  encoder__region_category+offer_application_pre...     0.00075
# 385     183    encoder__gender+last_visit_time_of_day_FMorning     0.00075
# 386    1273  encoder__past_complaint+joining_day_name_NoSat...     0.00075
# 387    1535  encoder__last_visit_time_of_day+joining_day_na...     0.00075
# 388    1474  encoder__feedback+joining_day_name_Poor Produc...     0.00075
# 389     815  encoder__preferred_offer_types+feedback_Gift V...     0.00075
# 390    1027  encoder__internet_option+complaint_status_Wi-F...     0.00075
# 391     654  encoder__joined_through_referral+preferred_off...     0.00075
# 392     704  encoder__joined_through_referral+feedback_NoPo...     0.00075
# 393    1529  encoder__last_visit_time_of_day+joining_day_na...     0.00074
# 394    1096  encoder__internet_option+joining_day_name_Wi-F...     0.00074
# 395     838  encoder__preferred_offer_types+last_visit_time...     0.00074
# 396    1048  encoder__internet_option+feedback_Wi-FiNo reas...     0.00074
# 397     449  encoder__membership_category+internet_option_P...     0.00074
# 398     387  encoder__membership_category+joined_through_re...     0.00074
# 399     155      encoder__gender+feedback_FNo reason specified     0.00074
# 400     631  encoder__membership_category+joining_day_name_...     0.00074
# 401     677  encoder__joined_through_referral+used_special_...     0.00074
# 402     603  encoder__membership_category+last_visit_AMPM_N...     0.00074
# 403    1379  encoder__complaint_status+joining_day_name_Sol...     0.00074
# 404     251  encoder__region_category+preferred_offer_types...     0.00074
# 405      90  encoder__gender+preferred_offer_types_FWithout...     0.00074
# 406    1517  encoder__feedback+joining_day_name_User Friend...     0.00074
# 407     886  encoder__medium_of_operation+used_special_disc...     0.00073
# 408     236  encoder__region_category+membership_category_V...     0.00073
# 409     395  encoder__membership_category+joined_through_re...     0.00073
# 410     941  encoder__medium_of_operation+feedback_Smartpho...     0.00073
# 411     388  encoder__membership_category+joined_through_re...     0.00073
# 412    1266       encoder__past_complaint+last_visit_AMPM_NoAM     0.00073
# 413     464  encoder__membership_category+used_special_disc...     0.00073
# 414     441  encoder__membership_category+internet_option_G...     0.00073
# 415     890  encoder__medium_of_operation+used_special_disc...     0.00073
# 416     874  encoder__preferred_offer_types+joining_day_nam...     0.00073
# 417    1078  encoder__internet_option+joining_day_name_Fibe...     0.00073
# 418     976  encoder__medium_of_operation+joining_day_name_...     0.00073
# 419     286  encoder__region_category+offer_application_pre...     0.00073
# 420    1382  encoder__complaint_status+joining_day_name_Sol...     0.00073
# 421     581  encoder__membership_category+last_visit_time_o...     0.00073
# 422     709  encoder__joined_through_referral+feedback_NoUs...     0.00073
# 423    1065  encoder__internet_option+last_visit_time_of_da...     0.00073
# 424     228  encoder__region_category+membership_category_C...     0.00073
# 425     777  encoder__preferred_offer_types+offer_applicati...     0.00073
# 426    1223  encoder__offer_application_preference+joining_...     0.00073
# 427    1215  encoder__offer_application_preference+last_vis...     0.00073
# 428    1504  encoder__feedback+joining_day_name_Reasonable ...     0.00073
# 429    1230  encoder__offer_application_preference+joining_...     0.00073
# 430     477  encoder__membership_category+offer_application...     0.00072
# 431     162             encoder__gender+feedback_FToo many ads     0.00072
# 432     863  encoder__preferred_offer_types+joining_day_nam...     0.00072
# 433     407  encoder__membership_category+preferred_offer_t...     0.00072
# 434     253  encoder__region_category+preferred_offer_types...     0.00072
# 435     840  encoder__preferred_offer_types+last_visit_time...     0.00072
# 436     974  encoder__medium_of_operation+joining_day_name_...     0.00072
# 437     948  encoder__medium_of_operation+feedback_Smartpho...     0.00072
# 438    1348  encoder__complaint_status+last_visit_time_of_d...     0.00072
# 439     135                encoder__gender+past_complaint_MYes     0.00072
# 440    1550  encoder__last_visit_time_of_day+joining_day_na...     0.00072
# 441     607  encoder__membership_category+last_visit_AMPM_P...     0.00072
# 442     670  encoder__joined_through_referral+internet_opti...     0.00072
# 443     664  encoder__joined_through_referral+medium_of_ope...     0.00072
# 444     158             encoder__gender+feedback_FPoor Website     0.00072
# 445     641  encoder__membership_category+joining_day_name_...     0.00072
# 446    1552  encoder__last_visit_time_of_day+joining_day_na...     0.00072
# 447     707  encoder__joined_through_referral+feedback_NoRe...     0.00072
# 448    1195  encoder__offer_application_preference+feedback...     0.00072
# 449    1205  encoder__offer_application_preference+last_vis...     0.00072
# 450    1314  encoder__complaint_status+feedback_SolvedPoor ...     0.00072
# 451    1316  encoder__complaint_status+feedback_SolvedPoor ...     0.00072
# 452     384  encoder__region_category+joining_day_name_Vill...     0.00072
# 453    1572                      scaler__avg_transaction_value     0.00072
# 454     656  encoder__joined_through_referral+preferred_off...     0.00072
# 455     366  encoder__region_category+joining_day_name_City...     0.00072
# 456     279  encoder__region_category+used_special_discount...     0.00072
# 457    1282  encoder__past_complaint+joining_day_name_YesTh...     0.00071
# 458    1482  encoder__feedback+joining_day_name_Poor Websit...     0.00071
# 459     479  encoder__membership_category+offer_application...     0.00071
# 460    1067  encoder__internet_option+last_visit_time_of_da...     0.00071
# 461    1026  encoder__internet_option+complaint_status_Wi-F...     0.00071
# 462     757  encoder__preferred_offer_types+medium_of_opera...     0.00071
# 463     779  encoder__preferred_offer_types+offer_applicati...     0.00071
# 464    1575                     scaler__points_per_transaction     0.00071
# 465     693  encoder__joined_through_referral+complaint_sta...     0.00071
# 466     127   encoder__gender+offer_application_preference_MNo     0.00071
# 467     824  encoder__preferred_offer_types+feedback_Withou...     0.00071
# 468    1131  encoder__used_special_discount+feedback_YesPoo...     0.00071
# 469      98          encoder__gender+medium_of_operation_FBoth     0.00071
# 470     103    encoder__gender+medium_of_operation_MSmartphone     0.00071
# 471    1005  encoder__internet_option+offer_application_pre...     0.00071
# 472    1177  encoder__offer_application_preference+complain...     0.00071
# 473     984  encoder__medium_of_operation+joining_day_name_...     0.00071
# 474     889  encoder__medium_of_operation+used_special_disc...     0.00070
# 475     391  encoder__membership_category+joined_through_re...     0.00070
# 476     359    encoder__region_category+last_visit_AMPM_TownAM     0.00070
# 477     355  encoder__region_category+last_visit_time_of_da...     0.00070
# 478    1149  encoder__used_special_discount+last_visit_AMPM...     0.00070
# 479     895  encoder__medium_of_operation+offer_application...     0.00070
# 480      53              encoder__gender+region_category_FTown     0.00070
# 481     955  encoder__medium_of_operation+last_visit_time_o...     0.00070
# 482     961  encoder__medium_of_operation+last_visit_time_o...     0.00070
# 483     944  encoder__medium_of_operation+feedback_Smartpho...     0.00070
# 484     559  encoder__membership_category+feedback_Premium ...     0.00070
# 485      55              encoder__gender+region_category_MCity     0.00070
# 486     735  encoder__joined_through_referral+joining_day_n...     0.00070
# 487     668  encoder__joined_through_referral+internet_opti...     0.00070
# 488      68  encoder__gender+membership_category_MBasic Mem...     0.00070
# 489    1311  encoder__complaint_status+feedback_Solved in F...     0.00070
# 490    1042  encoder__internet_option+feedback_Mobile_DataP...     0.00070
# 491    1486  encoder__feedback+joining_day_name_Products al...     0.00070
# 492    1008  encoder__internet_option+past_complaint_Fiber_...     0.00070
# 493    1060  encoder__internet_option+last_visit_time_of_da...     0.00070
# 494     721  encoder__joined_through_referral+last_visit_ti...     0.00070
# 495    1203  encoder__offer_application_preference+last_vis...     0.00070
# 496     224  encoder__region_category+membership_category_C...     0.00070
# 497    1361  encoder__complaint_status+last_visit_AMPM_Unso...     0.00069
# 498     819  encoder__preferred_offer_types+feedback_Gift V...     0.00069
# 499     591  encoder__membership_category+last_visit_time_o...     0.00069
# 500     367  encoder__region_category+joining_day_name_City...     0.00069
# 501     345  encoder__region_category+last_visit_time_of_da...     0.00069
# 502    1009  encoder__internet_option+past_complaint_Mobile...     0.00069
# 503     930  encoder__medium_of_operation+feedback_BothToo ...     0.00069
# 504     448  encoder__membership_category+internet_option_P...     0.00069
# 505     255  encoder__region_category+preferred_offer_types...     0.00069
# 506     869  encoder__preferred_offer_types+joining_day_nam...     0.00069
# 507    1443   encoder__feedback+last_visit_AMPM_Poor WebsiteAM     0.00069
# 508    1217  encoder__offer_application_preference+joining_...     0.00069
# 509     715  encoder__joined_through_referral+feedback_YesQ...     0.00069
# 510     522  encoder__membership_category+complaint_status_...     0.00069
# 511    1227  encoder__offer_application_preference+joining_...     0.00069
# 512    1357  encoder__complaint_status+last_visit_AMPM_Solv...     0.00069
# 513     988  encoder__medium_of_operation+joining_day_name_...     0.00069
# 514     657  encoder__joined_through_referral+preferred_off...     0.00069
# 515     204           encoder__gender+joining_day_name_FSunday     0.00068
# 516    1464  encoder__feedback+joining_day_name_Poor Custom...     0.00068
# 517     225  encoder__region_category+membership_category_C...     0.00068
# 518    1475  encoder__feedback+joining_day_name_Poor Produc...     0.00068
# 519     487  encoder__membership_category+past_complaint_No...     0.00068
# 520     763  encoder__preferred_offer_types+internet_option...     0.00068
# 521     855  encoder__preferred_offer_types+joining_day_nam...     0.00068
# 522    1002  encoder__internet_option+offer_application_pre...     0.00068
# 523     438  encoder__membership_category+internet_option_B...     0.00068
# 524     459  encoder__membership_category+used_special_disc...     0.00068
# 525    1412  encoder__feedback+last_visit_time_of_day_Poor ...     0.00068
# 526     959  encoder__medium_of_operation+last_visit_time_o...     0.00068
# 527    1526  encoder__last_visit_time_of_day+joining_day_na...     0.00068
# 528    1268      encoder__past_complaint+last_visit_AMPM_YesAM     0.00068
# 529    1161  encoder__used_special_discount+joining_day_nam...     0.00068
# 530     208           encoder__gender+joining_day_name_MFriday     0.00068
# 531    1501  encoder__feedback+joining_day_name_Reasonable ...     0.00068
# 532     118          encoder__gender+used_special_discount_FNo     0.00068
# 533     781  encoder__preferred_offer_types+offer_applicati...     0.00068
# 534    1041  encoder__internet_option+feedback_Mobile_DataP...     0.00068
# 535     239  encoder__region_category+membership_category_V...     0.00068
# 536     811  encoder__preferred_offer_types+feedback_Credit...     0.00068
# 537     818  encoder__preferred_offer_types+feedback_Gift V...     0.00068
# 538     658  encoder__joined_through_referral+preferred_off...     0.00067
# 539     281  encoder__region_category+used_special_discount...     0.00067
# 540     113             encoder__gender+internet_option_MWi-Fi     0.00067
# 541     375  encoder__region_category+joining_day_name_Town...     0.00067
# 542      39            encoder__last_visit_time_of_day_Evening     0.00067
# 543    1140  encoder__used_special_discount+last_visit_time...     0.00067
# 544    1564  encoder__last_visit_AMPM+joining_day_name_PMSu...     0.00067
# 545    1142  encoder__used_special_discount+last_visit_time...     0.00067
# 546    1451   encoder__feedback+last_visit_AMPM_Too many adsAM     0.00067
# 547     250  encoder__region_category+preferred_offer_types...     0.00067
# 548     599  encoder__membership_category+last_visit_AMPM_B...     0.00067
# 549     669  encoder__joined_through_referral+internet_opti...     0.00067
# 550    1547  encoder__last_visit_time_of_day+joining_day_na...     0.00067
# 551     702  encoder__joined_through_referral+feedback_NoPo...     0.00067
# 552    1032  encoder__internet_option+feedback_Fiber_OpticP...     0.00067
# 553    1471  encoder__feedback+joining_day_name_Poor Produc...     0.00067
# 554      73  encoder__gender+membership_category_MSilver Me...     0.00067
# 555    1245    encoder__past_complaint+feedback_NoToo many ads     0.00067
# 556    1136  encoder__used_special_discount+feedback_YesToo...     0.00067
# 557     270  encoder__region_category+internet_option_CityM...     0.00067
# 558     415  encoder__membership_category+preferred_offer_t...     0.00067
# 559    1276  encoder__past_complaint+joining_day_name_NoTue...     0.00067
# 560     799  encoder__preferred_offer_types+complaint_statu...     0.00067
# 561     759  encoder__preferred_offer_types+internet_option...     0.00067
# 562     159  encoder__gender+feedback_FProducts always in S...     0.00066
# 563     243  encoder__region_category+joined_through_referr...     0.00066
# 564    1428  encoder__feedback+last_visit_time_of_day_Too m...     0.00066
# 565     267  encoder__region_category+medium_of_operation_V...     0.00066
# 566    1173  encoder__offer_application_preference+complain...     0.00066
# 567      93  encoder__gender+preferred_offer_types_MWithout...     0.00066
# 568     260  encoder__region_category+medium_of_operation_C...     0.00066
# 569      36                 encoder__complaint_status_Unsolved     0.00066
# 570    1571                             scaler__avg_time_spent     0.00066
# 571     711  encoder__joined_through_referral+feedback_YesP...     0.00066
# 572     583  encoder__membership_category+last_visit_time_o...     0.00066
# 573     499  encoder__membership_category+complaint_status_...     0.00066
# 574     332  encoder__region_category+feedback_TownToo many...     0.00066
# 575     295     encoder__region_category+past_complaint_TownNo     0.00066
# 576     790  encoder__preferred_offer_types+complaint_statu...     0.00066
# 577     350  encoder__region_category+last_visit_time_of_da...     0.00066
# 578     871  encoder__preferred_offer_types+joining_day_nam...     0.00066
# 579     856  encoder__preferred_offer_types+joining_day_nam...     0.00066
# 580     673  encoder__joined_through_referral+internet_opti...     0.00066
# 581     132                 encoder__gender+past_complaint_FNo     0.00066
# 582     585  encoder__membership_category+last_visit_time_o...     0.00066
# 583    1033  encoder__internet_option+feedback_Fiber_OpticP...     0.00066
# 584     825  encoder__preferred_offer_types+feedback_Withou...     0.00066
# 585    1188  encoder__offer_application_preference+feedback...     0.00066
# 586     820  encoder__preferred_offer_types+feedback_Gift V...     0.00066
# 587     904  encoder__medium_of_operation+past_complaint_Sm...     0.00065
# 588     283  encoder__region_category+used_special_discount...     0.00065
# 589     620  encoder__membership_category+joining_day_name_...     0.00065
# 590     168  encoder__gender+feedback_MProducts always in S...     0.00065
# 591     289  encoder__region_category+offer_application_pre...     0.00065
# 592     287  encoder__region_category+offer_application_pre...     0.00065
# 593     900  encoder__medium_of_operation+past_complaint_Bo...     0.00065
# 594     383  encoder__region_category+joining_day_name_Vill...     0.00065
# 595     946  encoder__medium_of_operation+feedback_Smartpho...     0.00065
# 596     344  encoder__region_category+last_visit_time_of_da...     0.00065
# 597    1133  encoder__used_special_discount+feedback_YesPro...     0.00065
# 598    1130  encoder__used_special_discount+feedback_YesPoo...     0.00065
# 599    1116  encoder__used_special_discount+complaint_statu...     0.00065
# 600    1224  encoder__offer_application_preference+joining_...     0.00065
# 601     309  encoder__region_category+complaint_status_Town...     0.00065
# 602     807  encoder__preferred_offer_types+feedback_Credit...     0.00065
# 603     492  encoder__membership_category+past_complaint_Si...     0.00065
# 604    1332  encoder__complaint_status+last_visit_time_of_d...     0.00065
# 605     783  encoder__preferred_offer_types+past_complaint_...     0.00065
# 606     202           encoder__gender+joining_day_name_FMonday     0.00065
# 607    1187  encoder__offer_application_preference+feedback...     0.00065
# 608     141           encoder__gender+complaint_status_FSolved     0.00065
# 609     724  encoder__joined_through_referral+last_visit_ti...     0.00065
# 610    1478  encoder__feedback+joining_day_name_Poor Websit...     0.00065
# 611     701  encoder__joined_through_referral+feedback_NoNo...     0.00065
# 612    1569                                        scaler__age     0.00064
# 613     274  encoder__region_category+internet_option_TownW...     0.00064
# ...
# 1050               0.926591
# 1051               0.927031
# 1052               0.927471
# 1053               0.927911
# 1054               0.928351
# 1055               0.928791
# 1056               0.929231
# 1057               0.929671
# 1058               0.930111
# 1059               0.930551
# 1060               0.930991
# 1061               0.931431
# 1062               0.931871
# 1063               0.932311
# 1064               0.932741
# 1065               0.933171
# 1066               0.933601
# 1067               0.934031
# 1068               0.934461
# 1069               0.934891
# 1070               0.935321
# 1071               0.935751
# 1072               0.936181
# 1073               0.936611
# 1074               0.937041
# 1075               0.937471
# 1076               0.937901
# 1077               0.938331
# 1078               0.938761
# 1079               0.939181
# 1080               0.939601
# 1081               0.940021
# 1082               0.940441
# 1083               0.940861
# 1084               0.941281
# 1085               0.941701
# 1086               0.942121
# 1087               0.942541
# 1088               0.942951
# 1089               0.943361
# 1090               0.943771
# 1091               0.944181
# 1092               0.944591
# 1093               0.945001
# 1094               0.945411
# 1095               0.945811
# 1096               0.946211
# 1097               0.946611
# 1098               0.947011
# 1099               0.947411
# 1100               0.947811
# 1101               0.948211
# 1102               0.948611
# 1103               0.949011
# 1104               0.949411
# 1105               0.949811
# 1106               0.950211
# 1107               0.950611
# 1108               0.951011
# 1109               0.951411
# 1110               0.951811
# 1111               0.952211
# 1112               0.952611
# 1113               0.953011
# 1114               0.953401
# 1115               0.953791
# 1116               0.954181
# 1117               0.954571
# 1118               0.954961
# 1119               0.955351
# 1120               0.955741
# 1121               0.956131
# 1122               0.956521
# 1123               0.956911
# 1124               0.957301
# 1125               0.957691
# 1126               0.958071
# 1127               0.958451
# 1128               0.958831
# 1129               0.959211
# 1130               0.959591
# 1131               0.959971
# 1132               0.960351
# 1133               0.960721
# 1134               0.961091
# 1135               0.961461
# 1136               0.961831
# 1137               0.962201
# 1138               0.962571
# 1139               0.962941
# 1140               0.963311
# 1141               0.963681
# 1142               0.964051
# 1143               0.964421
# 1144               0.964791
# 1145               0.965151
# 1146               0.965511
# 1147               0.965871
# 1148               0.966231
# 1149               0.966591
# 1150               0.966951
# 1151               0.967301
# 1152               0.967651
# 1153               0.968001
# 1154               0.968351
# 1155               0.968701
# 1156               0.969051
# 1157               0.969401
# 1158               0.969751
# 1159               0.970101
# 1160               0.970441
# 1161               0.970781
# 1162               0.971121
# 1163               0.971461
# 1164               0.971801
# 1165               0.972141
# 1166               0.972481
# 1167               0.972821
# 1168               0.973161
# 1169               0.973501
# 1170               0.973831
# 1171               0.974161
# 1172               0.974491
# 1173               0.974821
# 1174               0.975141
# 1175               0.975461
# 1176               0.975781
# 1177               0.976101
# 1178               0.976421
# 1179               0.976731
# 1180               0.977041
# 1181               0.977351
# 1182               0.977661
# 1183               0.977971
# 1184               0.978281
# 1185               0.978591
# 1186               0.978901
# 1187               0.979201
# 1188               0.979501
# 1189               0.979791
# 1190               0.980081
# 1191               0.980371
# 1192               0.980661
# 1193               0.980951
# 1194               0.981241
# 1195               0.981531
# 1196               0.981811
# 1197               0.982091
# 1198               0.982371
# 1199               0.982651
# 1200               0.982931
# 1201               0.983211
# 1202               0.983491
# 1203               0.983771
# 1204               0.984051
# 1205               0.984331
# 1206               0.984611
# 1207               0.984891
# 1208               0.985171
# 1209               0.985451
# 1210               0.985721
# 1211               0.985991
# 1212               0.986261
# 1213               0.986531
# 1214               0.986801
# 1215               0.987071
# 1216               0.987341
# 1217               0.987601
# 1218               0.987861
# 1219               0.988121
# 1220               0.988381
# 1221               0.988641
# 1222               0.988901
# 1223               0.989161
# 1224               0.989421
# 1225               0.989681
# 1226               0.989941
# 1227               0.990201
# 1228               0.990461
# 1229               0.990711
# 1230               0.990961
# 1231               0.991211
# 1232               0.991461
# 1233               0.991711
# 1234               0.991951
# 1235               0.992191
# 1236               0.992431
# 1237               0.992671
# 1238               0.992911
# 1239               0.993151
# 1240               0.993391
# 1241               0.993621
# 1242               0.993851
# 1243               0.994081
# 1244               0.994311
# 1245               0.994541
# 1246               0.994751
# 1247               0.994961
# 1248               0.995171
# 1249               0.995381
# 1250               0.995591
# 1251               0.995791
# 1252               0.995991
# 1253               0.996191
# 1254               0.996391
# 1255               0.996591
# 1256               0.996781
# 1257               0.996971
# 1258               0.997161
# 1259               0.997351
# 1260               0.997531
# 1261               0.997701
# 1262               0.997871
# 1263               0.998041
# 1264               0.998211
# 1265               0.998381
# 1266               0.998541
# 1267               0.998701
# 1268               0.998841
# 1269               0.998971
# 1270               0.999091
# 1271               0.999211
# 1272               0.999331
# 1273               0.999441
# 1274               0.999551
# 1275               0.999661
# 1276               0.999761
# 1277               0.999861
# 1278               0.999961
# 1279               1.000011
# 1280               1.000021
# 1281               1.000021
# 1282               1.000021
# 1283               1.000021
# 1284               1.000021
# 1285               1.000021
# 1286               1.000021
# 1287               1.000021
# 1288               1.000021
# 1289               1.000021
# 1290               1.000021
# 1291               1.000021
# 1292               1.000021
# 1293               1.000021
# 1294               1.000021
# 1295               1.000021
# 1296               1.000021
# 1297               1.000021
# 1298               1.000021
# 1299               1.000021
# 1300               1.000021
# 1301               1.000021
# 1302               1.000021
# 1303               1.000021
# 1304               1.000021
# 1305               1.000021
# 1306               1.000021
# 1307               1.000021
# 1308               1.000021
# 1309               1.000021
# 1310               1.000021
# 1311               1.000021
# 1312               1.000021
# 1313               1.000021
# 1314               1.000021
# 1315               1.000021
# 1316               1.000021
# 1317               1.000021
# 1318               1.000021
# 1319               1.000021
# 1320               1.000021
# 1321               1.000021
# 1322               1.000021
# 1323               1.000021
# 1324               1.000021
# 1325               1.000021
# 1326               1.000021
# 1327               1.000021
# 1328               1.000021
# 1329               1.000021
# 1330               1.000021
# 1331               1.000021
# 1332               1.000021
# 1333               1.000021
# 1334               1.000021
# 1335               1.000021
# 1336               1.000021
# 1337               1.000021
# 1338               1.000021
# 1339               1.000021
# 1340               1.000021
# 1341               1.000021
# 1342               1.000021
# 1343               1.000021
# 1344               1.000021
# 1345               1.000021
# 1346               1.000021
# 1347               1.000021
# 1348               1.000021
# 1349               1.000021
# 1350               1.000021
# 1351               1.000021
# 1352               1.000021
# 1353               1.000021
# 1354               1.000021
# 1355               1.000021
# 1356               1.000021
# 1357               1.000021
# 1358               1.000021
# 1359               1.000021
# 1360               1.000021
# 1361               1.000021
# 1362               1.000021
# 1363               1.000021
# 1364               1.000021
# 1365               1.000021
# 1366               1.000021
# 1367               1.000021
# 1368               1.000021
# 1369               1.000021
# 1370               1.000021
# 1371               1.000021
# 1372               1.000021
# 1373               1.000021
# 1374               1.000021
# 1375               1.000021
# 1376               1.000021
# 1377               1.000021
# 1378               1.000021
# 1379               1.000021
# 1380               1.000021
# 1381               1.000021
# 1382               1.000021
# 1383               1.000021
# 1384               1.000021
# 1385               1.000021
# 1386               1.000021
# 1387               1.000021
# 1388               1.000021
# 1389               1.000021
# 1390               1.000021
# 1391               1.000021
# 1392               1.000021
# 1393               1.000021
# 1394               1.000021
# 1395               1.000021
# 1396               1.000021
# 1397               1.000021
# 1398               1.000021
# 1399               1.000021
# 1400               1.000021
# 1401               1.000021
# 1402               1.000021
# 1403               1.000021
# 1404               1.000021
# 1405               1.000021
# 1406               1.000021
# 1407               1.000021
# 1408               1.000021
# 1409               1.000021
# 1410               1.000021
# 1411               1.000021
# 1412               1.000021
# 1413               1.000021
# 1414               1.000021
# 1415               1.000021
# 1416               1.000021
# 1417               1.000021
# 1418               1.000021
# 1419               1.000021
# 1420               1.000021
# 1421               1.000021
# 1422               1.000021
# 1423               1.000021
# 1424               1.000021
# 1425               1.000021
# 1426               1.000021
# 1427               1.000021
# 1428               1.000021
# 1429               1.000021
# 1430               1.000021
# 1431               1.000021
# 1432               1.000021
# 1433               1.000021
# 1434               1.000021
# 1435               1.000021
# 1436               1.000021
# 1437               1.000021
# 1438               1.000021
# 1439               1.000021
# 1440               1.000021
# 1441               1.000021
# 1442               1.000021
# 1443               1.000021
# 1444               1.000021
# 1445               1.000021
# 1446               1.000021
# 1447               1.000021
# 1448               1.000021
# 1449               1.000021
# 1450               1.000021
# 1451               1.000021
# 1452               1.000021
# 1453               1.000021
# 1454               1.000021
# 1455               1.000021
# 1456               1.000021
# 1457               1.000021
# 1458               1.000021
# 1459               1.000021
# 1460               1.000021
# 1461               1.000021
# 1462               1.000021
# 1463               1.000021
# 1464               1.000021
# 1465               1.000021
# 1466               1.000021
# 1467               1.000021
# 1468               1.000021
# 1469               1.000021
# 1470               1.000021
# 1471               1.000021
# 1472               1.000021
# 1473               1.000021
# 1474               1.000021
# 1475               1.000021
# 1476               1.000021
# 1477               1.000021
# 1478               1.000021
# 1479               1.000021
# 1480               1.000021
# 1481               1.000021
# 1482               1.000021
# 1483               1.000021
# 1484               1.000021
# 1485               1.000021
# 1486               1.000021
# 1487               1.000021
# 1488               1.000021
# 1489               1.000021
# 1490               1.000021
# 1491               1.000021
# 1492               1.000021
# 1493               1.000021
# 1494               1.000021
# 1495               1.000021
# 1496               1.000021
# 1497               1.000021
# 1498               1.000021
# 1499               1.000021
# 1500               1.000021
# 1501               1.000021
# 1502               1.000021
# 1503               1.000021
# 1504               1.000021
# 1505               1.000021
# 1506               1.000021
# 1507               1.000021
# 1508               1.000021
# 1509               1.000021
# 1510               1.000021
# 1511               1.000021
# 1512               1.000021
# 1513               1.000021
# 1514               1.000021
# 1515               1.000021
# 1516               1.000021
# 1517               1.000021
# 1518               1.000021
# 1519               1.000021
# 1520               1.000021
# 1521               1.000021
# 1522               1.000021
# 1523               1.000021
# 1524               1.000021
# 1525               1.000021
# 1526               1.000021
# 1527               1.000021
# 1528               1.000021
# 1529               1.000021
# 1530               1.000021
# 1531               1.000021
# 1532               1.000021
# 1533               1.000021
# 1534               1.000021
# 1535               1.000021
# 1536               1.000021
# 1537               1.000021
# 1538               1.000021
# 1539               1.000021
# 1540               1.000021
# 1541               1.000021
# 1542               1.000021
# 1543               1.000021
# 1544               1.000021
# 1545               1.000021
# 1546               1.000021
# 1547               1.000021
# 1548               1.000021
# 1549               1.000021
# 1550               1.000021
# 1551               1.000021
# 1552               1.000021
# 1553               1.000021
# 1554               1.000021
# 1555               1.000021
# 1556               1.000021
# 1557               1.000021
# 1558               1.000021
# 1559               1.000021
# 1560               1.000021
# 1561               1.000021
# 1562               1.000021
# 1563               1.000021
# 1564               1.000021
# 1565               1.000021
# 1566               1.000021
# 1567               1.000021
# 1568               1.000021
# 1569               1.000021
# 1570               1.000021
# 1571               1.000021
# 1572               1.000021
# 1573               1.000021
# 1574               1.000021
# 1575               1.000021
# 1576               1.000021
# 1577               1.000021
# 1578               1.000021
# 1579               1.000021
# 1580               1.000021
# 1581               1.000021
# 1582               1.000021

# %%
# example
feature_importance_df.iloc[3, 1]
# Out:
# 'scaler__points_in_wallet'

# %%
pd.reset_option('display.max_rows')

# %%
# let's select the first 100 features where they have importance of around 30%
# important_features = feature_importance_df.iloc[:99]['index'].tolist()
# X_train_preprocessed_selected = X_train_preprocessed[:, important_features]
# ... let's continue this code in a separate notebook for model development!

# %% [markdown]
# ### Save preprocessed data (ready for modeling)

# %%
train_split_preprocessed = pd.concat([X_train_preprocessed, y_train], axis=1)
# use .parquet instead of .csv as the csv version is too large (> 100 MB),
# so it cannot be uploaded to GitHub
train_split_preprocessed.to_parquet('train_split_preprocessed.parquet', index=False)

# %% [markdown]
# ### Save pipelines & models

# %%
import joblib
joblib.dump(featureEng_encoder_scaler_pipeline, 'featureEng_encoder_scaler_pipeline.joblib')
joblib.dump(xgb_clf, 'xgb_clf_all_features.joblib')
# Out:
# ['xgb_clf_all_features.joblib']
